# %% [markdown]
# ###### ---0. Libraries---

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from IPython.display import display, HTML

# %%
df=pd.read_csv('data/attacks.csv',encoding='cp1252')
pd.set_option('display.max_rows', 10)
df
# Out:
#       Case Number         Date    Year        Type    Country
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA  \
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity
# 0           California     Oceanside, San Diego County     Paddling  \
# 1              Georgia  St. Simon Island, Glynn County     Standing
# 2               Hawaii                    Habush, Oahu      Surfing
# 3      New South Wales              Arrawarra Headland      Surfing
# 4               Colima                        La Ticla  Free diving
# ...                ...                             ...          ...
# 25718              NaN                             NaN          NaN
# 25719              NaN                             NaN          NaN
# 25720              NaN                             NaN          NaN
# 25721              NaN                             NaN          NaN
# 25722              NaN                             NaN          NaN
#
#                   Name Sex   ...         Species
# 0          Julie Wolfe    F  ...      White shark  \
# 1      Adyson McNeely     F  ...              NaN
# 2          John Denges    M  ...              NaN
# 3                 male    M  ...        2 m shark
# 4       Gustavo Ramos     M  ...  Tiger shark, 3m
# ...                ...  ...  ...              ...
# 25718              NaN  NaN  ...              NaN
# 25719              NaN  NaN  ...              NaN
# 25720              NaN  NaN  ...              NaN
# 25721              NaN  NaN  ...              NaN
# 25722              NaN  NaN  ...              NaN
#
#                Investigator or Source                       pdf
# 0                    R. Collier, GSAF      2018.06.25-Wolfe.pdf  \
# 1      K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2      K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3                      B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4                           A .Kipper      2018.06.04-Ramos.pdf
# ...                               ...                       ...
# 25718                             NaN                       NaN
# 25719                             NaN                       NaN
# 25720                             NaN                       NaN
# 25721                             NaN                       NaN
# 25722                             NaN                       NaN
#
#                                             href formula
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...  \
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 25718                                                NaN
# 25719                                                NaN
# 25720                                                NaN
# 25721                                                NaN
# 25722                                                NaN
#
#                                                     href Case Number.1
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25  \
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                  ...           ...
# 25718                                                NaN           NaN
# 25719                                                NaN           NaN
# 25720                                                NaN           NaN
# 25721                                                NaN           NaN
# 25722                                                NaN           NaN
#
#       Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0        2018.06.25         6303.0         NaN         NaN
# 1        2018.06.18         6302.0         NaN         NaN
# 2        2018.06.09         6301.0         NaN         NaN
# 3        2018.06.08         6300.0         NaN         NaN
# 4        2018.06.04         6299.0         NaN         NaN
# ...             ...            ...         ...         ...
# 25718           NaN            NaN         NaN         NaN
# 25719           NaN            NaN         NaN         NaN
# 25720           NaN            NaN         NaN         NaN
# 25721           NaN            NaN         NaN         NaN
# 25722           NaN            NaN         NaN         NaN
#
# [25723 rows x 24 columns]

# %%
df2=pd.read_csv('data/attacks.csv',encoding='cp1252')
df
# Out:
#       Case Number         Date    Year        Type    Country
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA  \
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity
# 0           California     Oceanside, San Diego County     Paddling  \
# 1              Georgia  St. Simon Island, Glynn County     Standing
# 2               Hawaii                    Habush, Oahu      Surfing
# 3      New South Wales              Arrawarra Headland      Surfing
# 4               Colima                        La Ticla  Free diving
# ...                ...                             ...          ...
# 25718              NaN                             NaN          NaN
# 25719              NaN                             NaN          NaN
# 25720              NaN                             NaN          NaN
# 25721              NaN                             NaN          NaN
# 25722              NaN                             NaN          NaN
#
#                   Name Sex   ...         Species
# 0          Julie Wolfe    F  ...      White shark  \
# 1      Adyson McNeely     F  ...              NaN
# 2          John Denges    M  ...              NaN
# 3                 male    M  ...        2 m shark
# 4       Gustavo Ramos     M  ...  Tiger shark, 3m
# ...                ...  ...  ...              ...
# 25718              NaN  NaN  ...              NaN
# 25719              NaN  NaN  ...              NaN
# 25720              NaN  NaN  ...              NaN
# 25721              NaN  NaN  ...              NaN
# 25722              NaN  NaN  ...              NaN
#
#                Investigator or Source                       pdf
# 0                    R. Collier, GSAF      2018.06.25-Wolfe.pdf  \
# 1      K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2      K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3                      B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4                           A .Kipper      2018.06.04-Ramos.pdf
# ...                               ...                       ...
# 25718                             NaN                       NaN
# 25719                             NaN                       NaN
# 25720                             NaN                       NaN
# 25721                             NaN                       NaN
# 25722                             NaN                       NaN
#
#                                             href formula
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...  \
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 25718                                                NaN
# 25719                                                NaN
# 25720                                                NaN
# 25721                                                NaN
# 25722                                                NaN
#
#                                                     href Case Number.1
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25  \
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                  ...           ...
# 25718                                                NaN           NaN
# 25719                                                NaN           NaN
# 25720                                                NaN           NaN
# 25721                                                NaN           NaN
# 25722                                                NaN           NaN
#
#       Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0        2018.06.25         6303.0         NaN         NaN
# 1        2018.06.18         6302.0         NaN         NaN
# 2        2018.06.09         6301.0         NaN         NaN
# 3        2018.06.08         6300.0         NaN         NaN
# 4        2018.06.04         6299.0         NaN         NaN
# ...             ...            ...         ...         ...
# 25718           NaN            NaN         NaN         NaN
# 25719           NaN            NaN         NaN         NaN
# 25720           NaN            NaN         NaN         NaN
# 25721           NaN            NaN         NaN         NaN
# 25722           NaN            NaN         NaN         NaN
#
# [25723 rows x 24 columns]

# %% [markdown]
# # 1. EXPLORATION

# %% [markdown]
# Hereby, we will analise which kind of type of data we are facing with, nº columns, null values, duplicated values, unwanted whitespaces, etc.

# %% [markdown]
# ### 1.1 Dimensions of the df

# %%
df2.shape
# Out:
# (25723, 24)

# %% [markdown]
# ### 1.2 Head of the df

# %% [markdown]
# #### Quick overview of the columns and some data

# %%
df2.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California  \
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...  \
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
#           Species           Investigator or Source                       pdf
# 0      White shark                R. Collier, GSAF      2018.06.25-Wolfe.pdf  \
# 1              NaN  K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2              NaN  K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3        2 m shark                  B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4  Tiger shark, 3m                       A .Kipper      2018.06.04-Ramos.pdf
#
#                                         href formula
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...  \
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25  \
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
#
#   Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0    2018.06.25         6303.0         NaN         NaN
# 1    2018.06.18         6302.0         NaN         NaN
# 2    2018.06.09         6301.0         NaN         NaN
# 3    2018.06.08         6300.0         NaN         NaN
# 4    2018.06.04         6299.0         NaN         NaN
#
# [5 rows x 24 columns]

# %%
df2.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %% [markdown]
# ### 1.3 Data types

# %%
pd.set_option('display.max_rows', 30)
df2.dtypes
# Out:
# Case Number                object
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Time                       object
# Species                    object
# Investigator or Source     object
# pdf                        object
# href formula               object
# href                       object
# Case Number.1              object
# Case Number.2              object
# original order            float64
# Unnamed: 22                object
# Unnamed: 23                object
# dtype: object

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
#  14  Species                 3464 non-null   object
#  15  Investigator or Source  6285 non-null   object
#  16  pdf                     6302 non-null   object
#  17  href formula            6301 non-null   object
#  18  href                    6302 non-null   object
#  19  Case Number.1           6302 non-null   object
#  20  Case Number.2           6302 non-null   object
#  21  original order          6309 non-null   float64
#  22  Unnamed: 22             1 non-null      object
#  23  Unnamed: 23             2 non-null      object
# dtypes: float64(2), object(22)
# memory usage: 4.7+ MB

# %% [markdown]
# ### 1.4 Duplicated data

# %% [markdown]
# #### 1.4.1. Columns:

# %% [markdown]
# After having seen the header, we realised that are some columns that potentially can be repeated:
#
#     - Case Number vs. Case Number.1 and Case Number.2
#     - Unnamed 22 and unnamed 23
#     - href and href formula

# %%
if df2['Case Number.1'].equals(df2['Case Number.2']):
    print('The CN 1 and CN2  have the same values')
else:
    print("They are not equals")
# Out:
# They are not equals

# %%
if df2['Case Number.1'].equals(df2['Case Number']):
    print('The CN 1 and CS  have the same values')
else:
    print("They are not equals")
# Out:
# They are not equals

# %%
if df2['Case Number.2'].equals(df2['Case Number']):
    print('The CN 1 and CS  have the same values')
else:
    print("They are not equals")
# Out:
# They are not equals

# %%
if df2['Unnamed: 22'].equals(df2['Unnamed: 23']):
    print('The Unnamed 22 and Unnamed 23 have the same values')
else:
    print("They are not equals")
# Out:
# They are not equals

# %%
if df2['href'].equals(df2['href formula']):
    print('The fh ref and href formula  have the same values')
else:
    print("They are not equals")
# Out:
# They are not equals

# %% [markdown]
# #### 1.4.2 Rows

# %%
if df.duplicated().any():
    print('There are duplicate rows in the dataframe')
else:
    print('There are no duplicate rows in the dataframe')
# Out:
# There are duplicate rows in the dataframe

# %% [markdown]
# There are some others columns date have redundant information as the columns: Case Number, Date, and Year. But for the moment we will keep it.

# %% [markdown]
# ###  1.5 Nulls

# %%
pd.isnull(df2).sum()
# Out:
# Case Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href formula              19422
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# Unnamed: 22               25722
# Unnamed: 23               25721
# dtype: int64

# %% [markdown]
# ###   -------------------------------------------------- Summary and conclusions--------------------------------------------------------

# %% [markdown]
# 1. The data it's not clean, there are many missing values, many empty rows and not consistency in the format of the registered information.
# 2. Before we start with the analysis, we need to clean accurately clean data. We will focus to this points:
#
#     - Clean repeated values in columns and rows
#     - Clean data when the content of one row is more than 50% empty
#     - Null Values
#
#                                                 TO TAKE INTO ACCOUNT:
#
#      2.1 High presence of null vallues in many of the columns arpund (4000-8000 per column). with this results, it's not            convenient to remove null straight away without doing a deepdive in our data. We will priorize to clean properly the            most important columns for our investigation, such us:
#         - 'Date', 'Year', 'Type', 'Country', 'Area', 'Location','Activity', 'Time', 'Species '
#
#      2.2 Even the results are that the Columns of Cane Number, Case Number 1, Case number 2 are not equals, the results              it's  not very conclusive as the data can't be clean and the results could be not accurate and consistent.
#
#      2.3 Columns Unnamed 22 and and Unammed 23 as they don't have any valuable informated, will be discarted of the analysy

# %% [markdown]
# # 2. Dataframe Cleaning data

# %% [markdown]
# 2.1 Remove rows with 50% of the cells empty

# %%
df_1 = df2.dropna(thresh=12) 
df_1
# Out:
#      Case Number         Date    Year        Type             Country
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA  \
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889     0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity
# 0            California          Oceanside, San Diego County      Paddling  \
# 1               Georgia       St. Simon Island, Glynn County      Standing
# 2                Hawaii                         Habush, Oahu       Surfing
# 3       New South Wales                   Arrawarra Headland       Surfing
# 4                Colima                             La Ticla   Free diving
# ...                 ...                                  ...           ...
# 6297  Western Australia                          Roebuck Bay        Diving
# 6298  Western Australia                                  NaN  Pearl diving
# 6299     North Carolina                       Ocracoke Inlet      Swimming
# 6300                NaN                 Panama Bay 8ºN, 79ºW           NaN
# 6301   Eastern Province  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex   ...         Species
# 0               Julie Wolfe    F  ...      White shark  \
# 1           Adyson McNeely     F  ...              NaN
# 2               John Denges    M  ...              NaN
# 3                      male    M  ...        2 m shark
# 4            Gustavo Ramos     M  ...  Tiger shark, 3m
# ...                     ...  ...  ...              ...
# 6297                   male    M  ...              NaN
# 6298                  Ahmun    M  ...              NaN
# 6299  Coast Guard personnel    M  ...              NaN
# 6300        Jules Patterson    M  ...              NaN
# 6301                   male    M  ...              NaN
#
#                      Investigator or Source                             pdf
# 0                          R. Collier, GSAF            2018.06.25-Wolfe.pdf  \
# 1            K.McMurray, TrackingSharks.com          2018.06.18-McNeely.pdf
# 2            K.McMurray, TrackingSharks.com           2018.06.09-Denges.pdf
# 3                            B. Myatt, GSAF        2018.06.08-Arrawarra.pdf
# 4                                 A .Kipper            2018.06.04-Ramos.pdf
# ...                                     ...                             ...
# 6297       H. Taunton; N. Bartlett,  p. 234          ND-0005-RoebuckBay.pdf
# 6298  H. Taunton; N. Bartlett,  pp. 233-234               ND-0004-Ahmun.pdf
# 6299   F. Schwartz, p.23; C. Creswell, GSAF  ND-0003-Ocracoke_1900-1905.pdf
# 6300                    The Sun, 10/20/1938      ND-0002-JulesPatterson.pdf
# 6301                             S.W. Baker              ND-0001-Ceylon.pdf
#
#                                            href formula
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...  \
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25  \
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                 ...           ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0005
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0004
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0003
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0002
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0001
#
#      Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0       2018.06.25         6303.0         NaN         NaN
# 1       2018.06.18         6302.0         NaN         NaN
# 2       2018.06.09         6301.0         NaN         NaN
# 3       2018.06.08         6300.0         NaN         NaN
# 4       2018.06.04         6299.0         NaN         NaN
# ...            ...            ...         ...         ...
# 6297       ND.0005            6.0         NaN         NaN
# 6298       ND.0004            5.0         NaN         NaN
# 6299       ND.0003            4.0         NaN         NaN
# 6300       ND.0002            3.0         NaN         NaN
# 6301       ND.0001            2.0         NaN         NaN
#
# [6302 rows x 24 columns]

# %% [markdown]
# 2.1 Remove rows with all the values are null

# %%
df_2 = df_1.dropna(how='all', axis=0)
df_2
# Out:
#      Case Number         Date    Year        Type             Country
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA  \
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889     0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity
# 0            California          Oceanside, San Diego County      Paddling  \
# 1               Georgia       St. Simon Island, Glynn County      Standing
# 2                Hawaii                         Habush, Oahu       Surfing
# 3       New South Wales                   Arrawarra Headland       Surfing
# 4                Colima                             La Ticla   Free diving
# ...                 ...                                  ...           ...
# 6297  Western Australia                          Roebuck Bay        Diving
# 6298  Western Australia                                  NaN  Pearl diving
# 6299     North Carolina                       Ocracoke Inlet      Swimming
# 6300                NaN                 Panama Bay 8ºN, 79ºW           NaN
# 6301   Eastern Province  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex   ...         Species
# 0               Julie Wolfe    F  ...      White shark  \
# 1           Adyson McNeely     F  ...              NaN
# 2               John Denges    M  ...              NaN
# 3                      male    M  ...        2 m shark
# 4            Gustavo Ramos     M  ...  Tiger shark, 3m
# ...                     ...  ...  ...              ...
# 6297                   male    M  ...              NaN
# 6298                  Ahmun    M  ...              NaN
# 6299  Coast Guard personnel    M  ...              NaN
# 6300        Jules Patterson    M  ...              NaN
# 6301                   male    M  ...              NaN
#
#                      Investigator or Source                             pdf
# 0                          R. Collier, GSAF            2018.06.25-Wolfe.pdf  \
# 1            K.McMurray, TrackingSharks.com          2018.06.18-McNeely.pdf
# 2            K.McMurray, TrackingSharks.com           2018.06.09-Denges.pdf
# 3                            B. Myatt, GSAF        2018.06.08-Arrawarra.pdf
# 4                                 A .Kipper            2018.06.04-Ramos.pdf
# ...                                     ...                             ...
# 6297       H. Taunton; N. Bartlett,  p. 234          ND-0005-RoebuckBay.pdf
# 6298  H. Taunton; N. Bartlett,  pp. 233-234               ND-0004-Ahmun.pdf
# 6299   F. Schwartz, p.23; C. Creswell, GSAF  ND-0003-Ocracoke_1900-1905.pdf
# 6300                    The Sun, 10/20/1938      ND-0002-JulesPatterson.pdf
# 6301                             S.W. Baker              ND-0001-Ceylon.pdf
#
#                                            href formula
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...  \
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25  \
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                 ...           ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0005
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0004
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0003
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0002
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0001
#
#      Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0       2018.06.25         6303.0         NaN         NaN
# 1       2018.06.18         6302.0         NaN         NaN
# 2       2018.06.09         6301.0         NaN         NaN
# 3       2018.06.08         6300.0         NaN         NaN
# 4       2018.06.04         6299.0         NaN         NaN
# ...            ...            ...         ...         ...
# 6297       ND.0005            6.0         NaN         NaN
# 6298       ND.0004            5.0         NaN         NaN
# 6299       ND.0003            4.0         NaN         NaN
# 6300       ND.0002            3.0         NaN         NaN
# 6301       ND.0001            2.0         NaN         NaN
#
# [6302 rows x 24 columns]

# %%
df_3= df_2.drop_duplicates(subset = ["Case Number.1", "Case Number.2"], inplace=False, keep="last")
df_3 # we drop Case Number 1 and 2 as contains the same info
# Out:
#      Case Number         Date    Year        Type             Country
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA  \
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889     0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity
# 0            California          Oceanside, San Diego County      Paddling  \
# 1               Georgia       St. Simon Island, Glynn County      Standing
# 2                Hawaii                         Habush, Oahu       Surfing
# 3       New South Wales                   Arrawarra Headland       Surfing
# 4                Colima                             La Ticla   Free diving
# ...                 ...                                  ...           ...
# 6297  Western Australia                          Roebuck Bay        Diving
# 6298  Western Australia                                  NaN  Pearl diving
# 6299     North Carolina                       Ocracoke Inlet      Swimming
# 6300                NaN                 Panama Bay 8ºN, 79ºW           NaN
# 6301   Eastern Province  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex   ...         Species
# 0               Julie Wolfe    F  ...      White shark  \
# 1           Adyson McNeely     F  ...              NaN
# 2               John Denges    M  ...              NaN
# 3                      male    M  ...        2 m shark
# 4            Gustavo Ramos     M  ...  Tiger shark, 3m
# ...                     ...  ...  ...              ...
# 6297                   male    M  ...              NaN
# 6298                  Ahmun    M  ...              NaN
# 6299  Coast Guard personnel    M  ...              NaN
# 6300        Jules Patterson    M  ...              NaN
# 6301                   male    M  ...              NaN
#
#                      Investigator or Source                             pdf
# 0                          R. Collier, GSAF            2018.06.25-Wolfe.pdf  \
# 1            K.McMurray, TrackingSharks.com          2018.06.18-McNeely.pdf
# 2            K.McMurray, TrackingSharks.com           2018.06.09-Denges.pdf
# 3                            B. Myatt, GSAF        2018.06.08-Arrawarra.pdf
# 4                                 A .Kipper            2018.06.04-Ramos.pdf
# ...                                     ...                             ...
# 6297       H. Taunton; N. Bartlett,  p. 234          ND-0005-RoebuckBay.pdf
# 6298  H. Taunton; N. Bartlett,  pp. 233-234               ND-0004-Ahmun.pdf
# 6299   F. Schwartz, p.23; C. Creswell, GSAF  ND-0003-Ocracoke_1900-1905.pdf
# 6300                    The Sun, 10/20/1938      ND-0002-JulesPatterson.pdf
# 6301                             S.W. Baker              ND-0001-Ceylon.pdf
#
#                                            href formula
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...  \
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25  \
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                 ...           ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0005
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0004
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0003
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0002
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0001
#
#      Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0       2018.06.25         6303.0         NaN         NaN
# 1       2018.06.18         6302.0         NaN         NaN
# 2       2018.06.09         6301.0         NaN         NaN
# 3       2018.06.08         6300.0         NaN         NaN
# 4       2018.06.04         6299.0         NaN         NaN
# ...            ...            ...         ...         ...
# 6297       ND.0005            6.0         NaN         NaN
# 6298       ND.0004            5.0         NaN         NaN
# 6299       ND.0003            4.0         NaN         NaN
# 6300       ND.0002            3.0         NaN         NaN
# 6301       ND.0001            2.0         NaN         NaN
#
# [6286 rows x 24 columns]

# %%
df_4= df_3.drop_duplicates(subset = ["href formula", "href"], inplace=False, keep="first")
df_4 # we drop Case Number 1 and 2 as contains the same info
# Out:
#      Case Number         Date    Year        Type             Country
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA  \
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889     0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity
# 0            California          Oceanside, San Diego County      Paddling  \
# 1               Georgia       St. Simon Island, Glynn County      Standing
# 2                Hawaii                         Habush, Oahu       Surfing
# 3       New South Wales                   Arrawarra Headland       Surfing
# 4                Colima                             La Ticla   Free diving
# ...                 ...                                  ...           ...
# 6297  Western Australia                          Roebuck Bay        Diving
# 6298  Western Australia                                  NaN  Pearl diving
# 6299     North Carolina                       Ocracoke Inlet      Swimming
# 6300                NaN                 Panama Bay 8ºN, 79ºW           NaN
# 6301   Eastern Province  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex   ...         Species
# 0               Julie Wolfe    F  ...      White shark  \
# 1           Adyson McNeely     F  ...              NaN
# 2               John Denges    M  ...              NaN
# 3                      male    M  ...        2 m shark
# 4            Gustavo Ramos     M  ...  Tiger shark, 3m
# ...                     ...  ...  ...              ...
# 6297                   male    M  ...              NaN
# 6298                  Ahmun    M  ...              NaN
# 6299  Coast Guard personnel    M  ...              NaN
# 6300        Jules Patterson    M  ...              NaN
# 6301                   male    M  ...              NaN
#
#                      Investigator or Source                             pdf
# 0                          R. Collier, GSAF            2018.06.25-Wolfe.pdf  \
# 1            K.McMurray, TrackingSharks.com          2018.06.18-McNeely.pdf
# 2            K.McMurray, TrackingSharks.com           2018.06.09-Denges.pdf
# 3                            B. Myatt, GSAF        2018.06.08-Arrawarra.pdf
# 4                                 A .Kipper            2018.06.04-Ramos.pdf
# ...                                     ...                             ...
# 6297       H. Taunton; N. Bartlett,  p. 234          ND-0005-RoebuckBay.pdf
# 6298  H. Taunton; N. Bartlett,  pp. 233-234               ND-0004-Ahmun.pdf
# 6299   F. Schwartz, p.23; C. Creswell, GSAF  ND-0003-Ocracoke_1900-1905.pdf
# 6300                    The Sun, 10/20/1938      ND-0002-JulesPatterson.pdf
# 6301                             S.W. Baker              ND-0001-Ceylon.pdf
#
#                                            href formula
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...  \
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25  \
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                 ...           ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0005
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0004
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0003
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0002
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0001
#
#      Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0       2018.06.25         6303.0         NaN         NaN
# 1       2018.06.18         6302.0         NaN         NaN
# 2       2018.06.09         6301.0         NaN         NaN
# 3       2018.06.08         6300.0         NaN         NaN
# 4       2018.06.04         6299.0         NaN         NaN
# ...            ...            ...         ...         ...
# 6297       ND.0005            6.0         NaN         NaN
# 6298       ND.0004            5.0         NaN         NaN
# 6299       ND.0003            4.0         NaN         NaN
# 6300       ND.0002            3.0         NaN         NaN
# 6301       ND.0001            2.0         NaN         NaN
#
# [6277 rows x 24 columns]

# %% [markdown]
# # YEARS - CLEANING DATA

# %% [markdown]
# - First, we are going to clean the column year to remove all the null values in year as we are not consider the ones empty.
# - As we we are going to considerer null values all the values that ar enot real years as "0, 5, 77, 500".
# - We are going to use a function that removes all the values in Year that does not contain 4 digits
# - Verify from which year are more attacks reported. With this assumption we check if before 80', maybe, many cases were not reported. With this we will have more accurate data about which is the ocean with more attacaks ommiting data that can make out data scatter- '''

# %%
df4 = df_4.dropna(subset=["Year"])
df4
# Out:
#      Case Number         Date    Year        Type             Country
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA  \
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889     0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity
# 0            California          Oceanside, San Diego County      Paddling  \
# 1               Georgia       St. Simon Island, Glynn County      Standing
# 2                Hawaii                         Habush, Oahu       Surfing
# 3       New South Wales                   Arrawarra Headland       Surfing
# 4                Colima                             La Ticla   Free diving
# ...                 ...                                  ...           ...
# 6297  Western Australia                          Roebuck Bay        Diving
# 6298  Western Australia                                  NaN  Pearl diving
# 6299     North Carolina                       Ocracoke Inlet      Swimming
# 6300                NaN                 Panama Bay 8ºN, 79ºW           NaN
# 6301   Eastern Province  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex   ...         Species
# 0               Julie Wolfe    F  ...      White shark  \
# 1           Adyson McNeely     F  ...              NaN
# 2               John Denges    M  ...              NaN
# 3                      male    M  ...        2 m shark
# 4            Gustavo Ramos     M  ...  Tiger shark, 3m
# ...                     ...  ...  ...              ...
# 6297                   male    M  ...              NaN
# 6298                  Ahmun    M  ...              NaN
# 6299  Coast Guard personnel    M  ...              NaN
# 6300        Jules Patterson    M  ...              NaN
# 6301                   male    M  ...              NaN
#
#                      Investigator or Source                             pdf
# 0                          R. Collier, GSAF            2018.06.25-Wolfe.pdf  \
# 1            K.McMurray, TrackingSharks.com          2018.06.18-McNeely.pdf
# 2            K.McMurray, TrackingSharks.com           2018.06.09-Denges.pdf
# 3                            B. Myatt, GSAF        2018.06.08-Arrawarra.pdf
# 4                                 A .Kipper            2018.06.04-Ramos.pdf
# ...                                     ...                             ...
# 6297       H. Taunton; N. Bartlett,  p. 234          ND-0005-RoebuckBay.pdf
# 6298  H. Taunton; N. Bartlett,  pp. 233-234               ND-0004-Ahmun.pdf
# 6299   F. Schwartz, p.23; C. Creswell, GSAF  ND-0003-Ocracoke_1900-1905.pdf
# 6300                    The Sun, 10/20/1938      ND-0002-JulesPatterson.pdf
# 6301                             S.W. Baker              ND-0001-Ceylon.pdf
#
#                                            href formula
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...  \
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25  \
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                 ...           ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0005
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0004
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0003
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0002
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0001
#
#      Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0       2018.06.25         6303.0         NaN         NaN
# 1       2018.06.18         6302.0         NaN         NaN
# 2       2018.06.09         6301.0         NaN         NaN
# 3       2018.06.08         6300.0         NaN         NaN
# 4       2018.06.04         6299.0         NaN         NaN
# ...            ...            ...         ...         ...
# 6297       ND.0005            6.0         NaN         NaN
# 6298       ND.0004            5.0         NaN         NaN
# 6299       ND.0003            4.0         NaN         NaN
# 6300       ND.0002            3.0         NaN         NaN
# 6301       ND.0001            2.0         NaN         NaN
#
# [6275 rows x 24 columns]

# %% [raw]
# verifying the values in column Year

# %%
df4['Year'].unique()
# Out:
# array([2018., 2017., 2016., 2015., 2014., 2013., 2012., 2011., 2010.,
#        2009., 2008., 2007., 2006., 2005., 2004., 2003., 2002., 2001.,
#        2000., 1999., 1998., 1997., 1996., 1995., 1984., 1994., 1993.,
#        1992., 1991., 1990., 1989., 1969., 1988., 1987., 1986., 1985.,
#        1983., 1982., 1981., 1980., 1979., 1978., 1977., 1976., 1975.,
#        1974., 1973., 1972., 1971., 1970., 1968., 1967., 1966., 1965.,
#        1964., 1963., 1962., 1961., 1960., 1959., 1958., 1957., 1956.,
#        1955., 1954., 1953., 1952., 1951., 1950., 1949., 1948., 1848.,
#        1947., 1946., 1945., 1944., 1943., 1942., 1941., 1940., 1939.,
#        1938., 1937., 1936., 1935., 1934., 1933., 1932., 1931., 1930.,
#        1929., 1928., 1927., 1926., 1925., 1924., 1923., 1922., 1921.,
#        1920., 1919., 1918., 1917., 1916., 1915., 1914., 1913., 1912.,
#        1911., 1910., 1909., 1908., 1907., 1906., 1905., 1904., 1903.,
#        1902., 1901., 1900., 1899., 1898., 1897., 1896., 1895., 1894.,
#        1893., 1892., 1891., 1890., 1889., 1888., 1887., 1886., 1885.,
#        1884., 1883., 1882., 1881., 1880., 1879., 1878., 1877., 1876.,
#        1875., 1874., 1873., 1872., 1871., 1870., 1869., 1868., 1867.,
#        1866., 1865., 1864., 1863., 1862., 1861., 1860., 1859., 1858.,
#        1857., 1856., 1855., 1853., 1852., 1851., 1850., 1849., 1847.,
#        1846., 1845., 1844., 1842., 1841., 1840., 1839., 1837., 1836.,
#        1835., 1834., 1832., 1831., 1830., 1829., 1828., 1827., 1826.,
#        1825., 1823., 1822., 1819., 1818., 1817., 1816., 1815., 1812.,
#        1811., 1810., 1808., 1807., 1805., 1804., 1803., 1802., 1801.,
#        1800., 1797., 1792., 1791., 1788., 1787., 1786., 1785., 1784.,
#        1783., 1780., 1779., 1776., 1771., 1767., 1764., 1758., 1753.,
#        1751., 1749., 1755., 1748., 1742., 1738., 1733., 1723., 1721.,
#        1703., 1700., 1642., 1638., 1637., 1617., 1595., 1580., 1555.,
#        1554., 1543.,  500.,   77.,    5.,    0.])

# %%
df5 = df4.dropna(subset=["Date"])
df5
# Out:
#      Case Number         Date    Year        Type             Country
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA  \
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889     0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity
# 0            California          Oceanside, San Diego County      Paddling  \
# 1               Georgia       St. Simon Island, Glynn County      Standing
# 2                Hawaii                         Habush, Oahu       Surfing
# 3       New South Wales                   Arrawarra Headland       Surfing
# 4                Colima                             La Ticla   Free diving
# ...                 ...                                  ...           ...
# 6297  Western Australia                          Roebuck Bay        Diving
# 6298  Western Australia                                  NaN  Pearl diving
# 6299     North Carolina                       Ocracoke Inlet      Swimming
# 6300                NaN                 Panama Bay 8ºN, 79ºW           NaN
# 6301   Eastern Province  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex   ...         Species
# 0               Julie Wolfe    F  ...      White shark  \
# 1           Adyson McNeely     F  ...              NaN
# 2               John Denges    M  ...              NaN
# 3                      male    M  ...        2 m shark
# 4            Gustavo Ramos     M  ...  Tiger shark, 3m
# ...                     ...  ...  ...              ...
# 6297                   male    M  ...              NaN
# 6298                  Ahmun    M  ...              NaN
# 6299  Coast Guard personnel    M  ...              NaN
# 6300        Jules Patterson    M  ...              NaN
# 6301                   male    M  ...              NaN
#
#                      Investigator or Source                             pdf
# 0                          R. Collier, GSAF            2018.06.25-Wolfe.pdf  \
# 1            K.McMurray, TrackingSharks.com          2018.06.18-McNeely.pdf
# 2            K.McMurray, TrackingSharks.com           2018.06.09-Denges.pdf
# 3                            B. Myatt, GSAF        2018.06.08-Arrawarra.pdf
# 4                                 A .Kipper            2018.06.04-Ramos.pdf
# ...                                     ...                             ...
# 6297       H. Taunton; N. Bartlett,  p. 234          ND-0005-RoebuckBay.pdf
# 6298  H. Taunton; N. Bartlett,  pp. 233-234               ND-0004-Ahmun.pdf
# 6299   F. Schwartz, p.23; C. Creswell, GSAF  ND-0003-Ocracoke_1900-1905.pdf
# 6300                    The Sun, 10/20/1938      ND-0002-JulesPatterson.pdf
# 6301                             S.W. Baker              ND-0001-Ceylon.pdf
#
#                                            href formula
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...  \
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25  \
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                 ...           ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0005
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0004
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0003
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0002
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0001
#
#      Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0       2018.06.25         6303.0         NaN         NaN
# 1       2018.06.18         6302.0         NaN         NaN
# 2       2018.06.09         6301.0         NaN         NaN
# 3       2018.06.08         6300.0         NaN         NaN
# 4       2018.06.04         6299.0         NaN         NaN
# ...            ...            ...         ...         ...
# 6297       ND.0005            6.0         NaN         NaN
# 6298       ND.0004            5.0         NaN         NaN
# 6299       ND.0003            4.0         NaN         NaN
# 6300       ND.0002            3.0         NaN         NaN
# 6301       ND.0001            2.0         NaN         NaN
#
# [6275 rows x 24 columns]

# %%
print(df5['Date'].unique())
pd.set_option('display.max_rows', 10)
# Out:
# ['25-Jun-2018' '18-Jun-2018' '09-Jun-2018' ... '1900-1905' '1883-1889'
#  '1845-1853']

# %% [markdown]
# As the values <1543 seems that they are incorrect, we will check if we can obtain this information from the column Date. In the column date, overall, we can find the exact day month and year of the attack. So, we are going to create extract the year (\4d) from this column to a new column .

# %%
df5['New_Year'] = df5['Date'] # create a new column with the same values as the original "Year" column

# %%
df5["All_years"] = df5["New_Year"].str.extract("(\d{4})")
df5
# Out:
#      Case Number         Date    Year        Type             Country
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA  \
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889     0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity
# 0            California          Oceanside, San Diego County      Paddling  \
# 1               Georgia       St. Simon Island, Glynn County      Standing
# 2                Hawaii                         Habush, Oahu       Surfing
# 3       New South Wales                   Arrawarra Headland       Surfing
# 4                Colima                             La Ticla   Free diving
# ...                 ...                                  ...           ...
# 6297  Western Australia                          Roebuck Bay        Diving
# 6298  Western Australia                                  NaN  Pearl diving
# 6299     North Carolina                       Ocracoke Inlet      Swimming
# 6300                NaN                 Panama Bay 8ºN, 79ºW           NaN
# 6301   Eastern Province  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex   ...                             pdf
# 0               Julie Wolfe    F  ...            2018.06.25-Wolfe.pdf  \
# 1           Adyson McNeely     F  ...          2018.06.18-McNeely.pdf
# 2               John Denges    M  ...           2018.06.09-Denges.pdf
# 3                      male    M  ...        2018.06.08-Arrawarra.pdf
# 4            Gustavo Ramos     M  ...            2018.06.04-Ramos.pdf
# ...                     ...  ...  ...                             ...
# 6297                   male    M  ...          ND-0005-RoebuckBay.pdf
# 6298                  Ahmun    M  ...               ND-0004-Ahmun.pdf
# 6299  Coast Guard personnel    M  ...  ND-0003-Ocracoke_1900-1905.pdf
# 6300        Jules Patterson    M  ...      ND-0002-JulesPatterson.pdf
# 6301                   male    M  ...              ND-0001-Ceylon.pdf
#
#                                            href formula
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...  \
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25  \
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                 ...           ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0005
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0004
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0003
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0002
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0001
#
#      Case Number.2 original order Unnamed: 22 Unnamed: 23     New_Year
# 0       2018.06.25         6303.0         NaN         NaN  25-Jun-2018  \
# 1       2018.06.18         6302.0         NaN         NaN  18-Jun-2018
# 2       2018.06.09         6301.0         NaN         NaN  09-Jun-2018
# 3       2018.06.08         6300.0         NaN         NaN  08-Jun-2018
# 4       2018.06.04         6299.0         NaN         NaN  04-Jun-2018
# ...            ...            ...         ...         ...          ...
# 6297       ND.0005            6.0         NaN         NaN  Before 1903
# 6298       ND.0004            5.0         NaN         NaN  Before 1903
# 6299       ND.0003            4.0         NaN         NaN    1900-1905
# 6300       ND.0002            3.0         NaN         NaN    1883-1889
# 6301       ND.0001            2.0         NaN         NaN    1845-1853
#
#      All_years
# 0         2018
# 1         2018
# 2         2018
# 3         2018
# 4         2018
# ...        ...
# 6297      1903
# 6298      1903
# 6299      1900
# 6300      1883
# 6301      1845
#
# [6275 rows x 26 columns]

# %%
df6 = df5.dropna(subset=["All_years"])
df6
# Out:
#      Case Number         Date    Year        Type             Country
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA  \
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889     0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity
# 0            California          Oceanside, San Diego County      Paddling  \
# 1               Georgia       St. Simon Island, Glynn County      Standing
# 2                Hawaii                         Habush, Oahu       Surfing
# 3       New South Wales                   Arrawarra Headland       Surfing
# 4                Colima                             La Ticla   Free diving
# ...                 ...                                  ...           ...
# 6297  Western Australia                          Roebuck Bay        Diving
# 6298  Western Australia                                  NaN  Pearl diving
# 6299     North Carolina                       Ocracoke Inlet      Swimming
# 6300                NaN                 Panama Bay 8ºN, 79ºW           NaN
# 6301   Eastern Province  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex   ...                             pdf
# 0               Julie Wolfe    F  ...            2018.06.25-Wolfe.pdf  \
# 1           Adyson McNeely     F  ...          2018.06.18-McNeely.pdf
# 2               John Denges    M  ...           2018.06.09-Denges.pdf
# 3                      male    M  ...        2018.06.08-Arrawarra.pdf
# 4            Gustavo Ramos     M  ...            2018.06.04-Ramos.pdf
# ...                     ...  ...  ...                             ...
# 6297                   male    M  ...          ND-0005-RoebuckBay.pdf
# 6298                  Ahmun    M  ...               ND-0004-Ahmun.pdf
# 6299  Coast Guard personnel    M  ...  ND-0003-Ocracoke_1900-1905.pdf
# 6300        Jules Patterson    M  ...      ND-0002-JulesPatterson.pdf
# 6301                   male    M  ...              ND-0001-Ceylon.pdf
#
#                                            href formula
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...  \
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25  \
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                 ...           ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0005
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0004
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0003
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0002
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0001
#
#      Case Number.2 original order Unnamed: 22 Unnamed: 23     New_Year
# 0       2018.06.25         6303.0         NaN         NaN  25-Jun-2018  \
# 1       2018.06.18         6302.0         NaN         NaN  18-Jun-2018
# 2       2018.06.09         6301.0         NaN         NaN  09-Jun-2018
# 3       2018.06.08         6300.0         NaN         NaN  08-Jun-2018
# 4       2018.06.04         6299.0         NaN         NaN  04-Jun-2018
# ...            ...            ...         ...         ...          ...
# 6297       ND.0005            6.0         NaN         NaN  Before 1903
# 6298       ND.0004            5.0         NaN         NaN  Before 1903
# 6299       ND.0003            4.0         NaN         NaN    1900-1905
# 6300       ND.0002            3.0         NaN         NaN    1883-1889
# 6301       ND.0001            2.0         NaN         NaN    1845-1853
#
#      All_years
# 0         2018
# 1         2018
# 2         2018
# 3         2018
# 4         2018
# ...        ...
# 6297      1903
# 6298      1903
# 6299      1900
# 6300      1883
# 6301      1845
#
# [6256 rows x 26 columns]

# %%
print(df6['All_years'].unique()) # verifying the extraction
# Out:
# ['2018' '2017' '2016' '2015' '2014' '2013' '2012' '2011' '2008' '2010'
#  '2009' '2006' '2007' '2005' '2004' '2003' '2002' '2001' '2000' '1999'
#  '1998' '1997' '1996' '1995' '1984' '1994' '1993' '1992' '1991' '1990'
#  '1989' '1988' '1987' '1986' '1985' '1983' '1982' '1981' '1980' '1979'
#  '1978' '1977' '1976' '1975' '1974' '1973' '1972' '1971' '1970' '1969'
#  '1968' '1967' '1966' '1965' '1964' '1954' '1963' '1962' '1961' '1960'
#  '1959' '2176' '1958' '1957' '1956' '1955' '1953' '1952' '1951' '1950'
#  '1949' '1948' '1848' '1947' '1946' '1945' '1944' '1943' '1942' '1941'
#  '1940' '1939' '1938' '1937' '1936' '1935' '1934' '1933' '1932' '1931'
#  '1930' '1929' '1928' '1927' '1926' '1925' '1924' '1923' '1922' '1921'
#  '1920' '1919' '1918' '1917' '1916' '1915' '1914' '1913' '1912' '1911'
#  '1910' '1909' '1908' '1907' '1906' '1905' '1904' '1903' '1902' '1901'
#  '1900' '1899' '1898' '1897' '1896' '1895' '1894' '1893' '1892' '1891'
#  '1890' '1889' '1888' '1887' '1886' '1885' '1884' '1883' '1882' '1881'
#  '1880' '1879' '1878' '1877' '1876' '1875' '1874' '1870' '1873' '1872'
#  '1871' '1869' '1868' '1867' '1866' '1865' '1864' '1863' '1862' '1861'
#  '1860' '1859' '1858' '1857' '1856' '1855' '1853' '1852' '1850' '1851'
#  '1849' '1847' '1846' '1845' '1844' '1842' '1841' '1840' '1839' '1837'
#  '1836' '1835' '1834' '1832' '1831' '1830' '1829' '1828' '1827' '1826'
#  '1820' '1825' '1823' '1822' '1819' '1818' '1817' '1816' '1815' '1812'
#  '1811' '1810' '1808' '1807' '1806' '1805' '1804' '1803' '1802' '1801'
#  '1800' '1797' '1792' '1791' '1788' '1787' '1786' '1785' '1784' '1783'
#  '1780' '1779' '1776' '1771' '1767' '1764' '1758' '1753' '1751' '1749'
#  '1755' '1748' '1742' '1738' '1733' '1723' '1721' '1703' '1700' '1600'
#  '1638' '1637' '1617' '1642' '1595' '1580' '1555' '1554' '1543']

# %% [markdown]
# Once we have all the years in teh column All years, we want extract this years to the column Years when the value is <1542 as they are the incorrect ones.

# %%
df6['Year'] = df6['Year'].astype(int)
df6['All_years'] = df6['All_years'].astype(int)
df6.loc[df4['Year'] < 1542, 'Year'] = df6.loc[df4['Year'] < 1542, 'All_years']
df6
# Out:
# C:\Users\Leticia Martinez\AppData\Local\Temp\ipykernel_10416\2207152789.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df6['Year'] = df6['Year'].astype(int)
# C:\Users\Leticia Martinez\AppData\Local\Temp\ipykernel_10416\2207152789.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df6['All_years'] = df6['All_years'].astype(int)
#      Case Number         Date  Year        Type             Country
# 0     2018.06.25  25-Jun-2018  2018     Boating                 USA  \
# 1     2018.06.18  18-Jun-2018  2018  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018    Provoked              MEXICO
# ...          ...          ...   ...         ...                 ...
# 6297     ND.0005  Before 1903  1903  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903  1903  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905  1900  Unprovoked                 USA
# 6300     ND.0002    1883-1889  1883  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853  1845  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity
# 0            California          Oceanside, San Diego County      Paddling  \
# 1               Georgia       St. Simon Island, Glynn County      Standing
# 2                Hawaii                         Habush, Oahu       Surfing
# 3       New South Wales                   Arrawarra Headland       Surfing
# 4                Colima                             La Ticla   Free diving
# ...                 ...                                  ...           ...
# 6297  Western Australia                          Roebuck Bay        Diving
# 6298  Western Australia                                  NaN  Pearl diving
# 6299     North Carolina                       Ocracoke Inlet      Swimming
# 6300                NaN                 Panama Bay 8ºN, 79ºW           NaN
# 6301   Eastern Province  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex   ...                             pdf
# 0               Julie Wolfe    F  ...            2018.06.25-Wolfe.pdf  \
# 1           Adyson McNeely     F  ...          2018.06.18-McNeely.pdf
# 2               John Denges    M  ...           2018.06.09-Denges.pdf
# 3                      male    M  ...        2018.06.08-Arrawarra.pdf
# 4            Gustavo Ramos     M  ...            2018.06.04-Ramos.pdf
# ...                     ...  ...  ...                             ...
# 6297                   male    M  ...          ND-0005-RoebuckBay.pdf
# 6298                  Ahmun    M  ...               ND-0004-Ahmun.pdf
# 6299  Coast Guard personnel    M  ...  ND-0003-Ocracoke_1900-1905.pdf
# 6300        Jules Patterson    M  ...      ND-0002-JulesPatterson.pdf
# 6301                   male    M  ...              ND-0001-Ceylon.pdf
#
#                                            href formula
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...  \
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25  \
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                 ...           ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0005
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0004
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0003
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0002
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0001
#
#      Case Number.2 original order Unnamed: 22 Unnamed: 23     New_Year
# 0       2018.06.25         6303.0         NaN         NaN  25-Jun-2018  \
# 1       2018.06.18         6302.0         NaN         NaN  18-Jun-2018
# 2       2018.06.09         6301.0         NaN         NaN  09-Jun-2018
# 3       2018.06.08         6300.0         NaN         NaN  08-Jun-2018
# 4       2018.06.04         6299.0         NaN         NaN  04-Jun-2018
# ...            ...            ...         ...         ...          ...
# 6297       ND.0005            6.0         NaN         NaN  Before 1903
# 6298       ND.0004            5.0         NaN         NaN  Before 1903
# 6299       ND.0003            4.0         NaN         NaN    1900-1905
# 6300       ND.0002            3.0         NaN         NaN    1883-1889
# 6301       ND.0001            2.0         NaN         NaN    1845-1853
#
#      All_years
# 0         2018
# 1         2018
# 2         2018
# 3         2018
# 4         2018
# ...        ...
# 6297      1903
# 6298      1903
# 6299      1900
# 6300      1883
# 6301      1845
#
# [6256 rows x 26 columns]

# %%
print(df6['Year'].unique()) # verifying the extraction
# Out:
# [2018 2017 2016 2015 2014 2013 2012 2011 2010 2009 2008 2007 2006 2005
#  2004 2003 2002 2001 2000 1999 1998 1997 1996 1995 1984 1994 1993 1992
#  1991 1990 1989 1969 1988 1987 1986 1985 1983 1982 1981 1980 1979 1978
#  1977 1976 1975 1974 1973 1972 1971 1970 1968 1967 1966 1965 1964 1963
#  1962 1961 1960 1959 1958 1957 1956 1955 1954 1953 1952 1951 1950 1949
#  1948 1848 1947 1946 1945 1944 1943 1942 1941 1940 1939 1938 1937 1936
#  1935 1934 1933 1932 1931 1930 1929 1928 1927 1926 1925 1924 1923 1922
#  1921 1920 1919 1918 1917 1916 1915 1914 1913 1912 1911 1910 1909 1908
#  1907 1906 1905 1904 1903 1902 1901 1900 1899 1898 1897 1896 1895 1894
#  1893 1892 1891 1890 1889 1888 1887 1886 1885 1884 1883 1882 1881 1880
#  1879 1878 1877 1876 1875 1874 1873 1872 1871 1870 1869 1868 1867 1866
#  1865 1864 1863 1862 1861 1860 1859 1858 1857 1856 1855 1853 1852 1851
#  1850 1849 1847 1846 1845 1844 1842 1841 1840 1839 1837 1836 1835 1834
#  1832 1831 1830 1829 1828 1827 1826 1825 1823 1822 1819 1818 1817 1816
#  1815 1812 1811 1810 1808 1807 1805 1804 1803 1802 1801 1800 1797 1792
#  1791 1788 1787 1786 1785 1784 1783 1780 1779 1776 1771 1767 1764 1758
#  1753 1751 1749 1755 1748 1742 1738 1733 1723 1721 1703 1700 1642 1638
#  1637 1617 1595 1580 1555 1554 1543]

# %% [markdown]
# ----------------------------------------year cleaning data finished------------------------------------------------------------

# %% [markdown]
# # COUNTRIES - CLEANING DATA

# %% [markdown]
#     First, we are going to verify which kind of data we are facing with:
#
#        - Null values? Can we get this data from anywhere else?
#        - Type Values
#        - Typo values?

# %%
print(df6['Country'].unique())
# Out:
# ['USA' 'AUSTRALIA' 'MEXICO' 'BRAZIL' 'ENGLAND' 'SOUTH AFRICA' 'THAILAND'
#  'COSTA RICA' 'MALDIVES' 'BAHAMAS' 'NEW CALEDONIA' 'ECUADOR' 'MALAYSIA'
#  'LIBYA' nan 'CUBA' 'MAURITIUS' 'NEW ZEALAND' 'SPAIN' 'SAMOA'
#  'SOLOMON ISLANDS' 'JAPAN' 'EGYPT' 'ST HELENA, British overseas territory'
#  'COMOROS' 'REUNION' 'FRENCH POLYNESIA' 'UNITED KINGDOM'
#  'UNITED ARAB EMIRATES' 'PHILIPPINES' 'INDONESIA' 'CHINA' 'COLUMBIA'
#  'CAPE VERDE' 'Fiji' 'DOMINICAN REPUBLIC' 'CAYMAN ISLANDS' 'ARUBA'
#  'MOZAMBIQUE' 'FIJI' 'PUERTO RICO' 'ITALY' 'ATLANTIC OCEAN' 'GREECE'
#  'ST. MARTIN' 'FRANCE' 'PAPUA NEW GUINEA' 'TRINIDAD & TOBAGO' 'KIRIBATI'
#  'ISRAEL' 'DIEGO GARCIA' 'TAIWAN' 'JAMAICA' 'PALESTINIAN TERRITORIES'
#  'GUAM' 'SEYCHELLES' 'BELIZE' 'NIGERIA' 'TONGA' 'SCOTLAND' 'CANADA'
#  'CROATIA' 'SAUDI ARABIA' 'CHILE' 'ANTIGUA' 'KENYA' 'RUSSIA'
#  'TURKS & CAICOS' 'UNITED ARAB EMIRATES (UAE)' 'AZORES' 'SOUTH KOREA'
#  'MALTA' 'VIETNAM' 'MADAGASCAR' 'PANAMA' 'SOMALIA' 'NEVIS'
#  'BRITISH VIRGIN ISLANDS' 'NORWAY' 'SENEGAL' 'YEMEN' 'GULF OF ADEN'
#  'Sierra Leone' 'ST. MAARTIN' 'GRAND CAYMAN' 'Seychelles' 'LIBERIA'
#  'VANUATU' 'MEXICO ' 'HONDURAS' 'VENEZUELA' 'SRI LANKA' ' TONGA' 'URUGUAY'
#  'INDIA' 'MICRONESIA' 'CARIBBEAN SEA' 'OKINAWA' 'TANZANIA'
#  'MARSHALL ISLANDS' 'EGYPT / ISRAEL' 'NORTHERN ARABIAN SEA' 'HONG KONG'
#  'EL SALVADOR' 'ANGOLA' 'BERMUDA' 'MONTENEGRO' 'IRAN' 'TUNISIA' 'NAMIBIA'
#  'NORTH ATLANTIC OCEAN' 'PORTUGAL' 'SOUTH CHINA SEA' 'BANGLADESH' 'PALAU'
#  'WESTERN SAMOA' 'PACIFIC OCEAN ' 'BRITISH ISLES' 'GRENADA' 'IRAQ'
#  'TURKEY' 'NEW BRITAIN' 'SUDAN' 'JOHNSTON ISLAND' 'SOUTH PACIFIC OCEAN'
#  'NEW GUINEA' 'RED SEA' 'NORTH PACIFIC OCEAN'
#  'FEDERATED STATES OF MICRONESIA' 'MID ATLANTIC OCEAN' 'ADMIRALTY ISLANDS'
#  'BRITISH WEST INDIES' 'SOUTH ATLANTIC OCEAN' 'PERSIAN GULF'
#  'RED SEA / INDIAN OCEAN' 'PACIFIC OCEAN' 'NORTH SEA' 'NICARAGUA '
#  'MALDIVE ISLANDS' 'AMERICAN SAMOA' 'ANDAMAN / NICOBAR ISLANDAS' 'GABON'
#  'MAYOTTE' 'NORTH ATLANTIC OCEAN ' 'SINGAPORE' 'THE BALKANS' 'SUDAN?'
#  'ARGENTINA' 'MARTINIQUE' 'INDIAN OCEAN' 'GUATEMALA'
#  'NETHERLANDS ANTILLES' 'NORTHERN MARIANA ISLANDS' 'IRAN / IRAQ' 'JAVA'
#  'SIERRA LEONE' ' PHILIPPINES' 'NICARAGUA' 'CENTRAL PACIFIC'
#  'SOLOMON ISLANDS / VANUATU' 'SOUTHWEST PACIFIC OCEAN' 'BAY OF BENGAL'
#  'MID-PACIFC OCEAN' 'SLOVENIA' 'CURACAO' 'ICELAND' 'ITALY / CROATIA'
#  'BARBADOS' 'MONACO' 'GUYANA' 'HAITI' 'SAN DOMINGO' 'IRELAND' 'KUWAIT'
#  'YEMEN ' 'REUNION ISLAND' 'FALKLAND ISLANDS' 'CRETE' 'CYPRUS' 'EGYPT '
#  'WEST INDIES' 'BURMA' 'LEBANON' 'PARAGUAY' 'BRITISH NEW GUINEA' 'CEYLON'
#  'OCEAN' 'GEORGIA' 'TUVALU' 'INDIAN OCEAN?' 'GUINEA' 'ANDAMAN ISLANDS'
#  'EQUATORIAL GUINEA / CAMEROON' 'COOK ISLANDS' 'TOBAGO' 'PERU' 'AFRICA'
#  'ALGERIA' 'Coast of AFRICA' 'TASMAN SEA' 'GHANA' 'GREENLAND'
#  'MEDITERRANEAN SEA' 'SWEDEN' 'ROATAN' 'Between PORTUGAL & INDIA'
#  'DJIBOUTI' 'BAHREIN' 'KOREA' 'RED SEA?' 'ASIA?' 'CEYLON (SRI LANKA)']

# %% [markdown]
# #### Findings:
#     - Null values
#     - 2 countries in the same cell
#     - Oceans instead of Countries --> ACTION TO BE TAKEN: try to find this information in other columns as Area or Location
#     - Regions instead of countres
#     - Most of the valeus are in uppercase but there are some in lower.

# %%
print(df6['Country'].dtype)
# Out:
# object

# %%
n_nulls = df6['Country'].isnull().sum() #48 null values
print(n_nulls)
# Out:
# 48

# %% [markdown]
# For the values that are null in Country, we try to see if there is information in the column Area in order to move these data to Country

# %%
df6.loc[df6['Country'].isnull(), 'Country'] = df6['Area'] 
df6
# Out:
#      Case Number         Date  Year        Type             Country
# 0     2018.06.25  25-Jun-2018  2018     Boating                 USA  \
# 1     2018.06.18  18-Jun-2018  2018  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018    Provoked              MEXICO
# ...          ...          ...   ...         ...                 ...
# 6297     ND.0005  Before 1903  1903  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903  1903  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905  1900  Unprovoked                 USA
# 6300     ND.0002    1883-1889  1883  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853  1845  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity
# 0            California          Oceanside, San Diego County      Paddling  \
# 1               Georgia       St. Simon Island, Glynn County      Standing
# 2                Hawaii                         Habush, Oahu       Surfing
# 3       New South Wales                   Arrawarra Headland       Surfing
# 4                Colima                             La Ticla   Free diving
# ...                 ...                                  ...           ...
# 6297  Western Australia                          Roebuck Bay        Diving
# 6298  Western Australia                                  NaN  Pearl diving
# 6299     North Carolina                       Ocracoke Inlet      Swimming
# 6300                NaN                 Panama Bay 8ºN, 79ºW           NaN
# 6301   Eastern Province  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex   ...                             pdf
# 0               Julie Wolfe    F  ...            2018.06.25-Wolfe.pdf  \
# 1           Adyson McNeely     F  ...          2018.06.18-McNeely.pdf
# 2               John Denges    M  ...           2018.06.09-Denges.pdf
# 3                      male    M  ...        2018.06.08-Arrawarra.pdf
# 4            Gustavo Ramos     M  ...            2018.06.04-Ramos.pdf
# ...                     ...  ...  ...                             ...
# 6297                   male    M  ...          ND-0005-RoebuckBay.pdf
# 6298                  Ahmun    M  ...               ND-0004-Ahmun.pdf
# 6299  Coast Guard personnel    M  ...  ND-0003-Ocracoke_1900-1905.pdf
# 6300        Jules Patterson    M  ...      ND-0002-JulesPatterson.pdf
# 6301                   male    M  ...              ND-0001-Ceylon.pdf
#
#                                            href formula
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...  \
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25  \
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                 ...           ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0005
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0004
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0003
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0002
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0001
#
#      Case Number.2 original order Unnamed: 22 Unnamed: 23     New_Year
# 0       2018.06.25         6303.0         NaN         NaN  25-Jun-2018  \
# 1       2018.06.18         6302.0         NaN         NaN  18-Jun-2018
# 2       2018.06.09         6301.0         NaN         NaN  09-Jun-2018
# 3       2018.06.08         6300.0         NaN         NaN  08-Jun-2018
# 4       2018.06.04         6299.0         NaN         NaN  04-Jun-2018
# ...            ...            ...         ...         ...          ...
# 6297       ND.0005            6.0         NaN         NaN  Before 1903
# 6298       ND.0004            5.0         NaN         NaN  Before 1903
# 6299       ND.0003            4.0         NaN         NaN    1900-1905
# 6300       ND.0002            3.0         NaN         NaN    1883-1889
# 6301       ND.0001            2.0         NaN         NaN    1845-1853
#
#      All_years
# 0         2018
# 1         2018
# 2         2018
# 3         2018
# 4         2018
# ...        ...
# 6297      1903
# 6298      1903
# 6299      1900
# 6300      1883
# 6301      1845
#
# [6256 rows x 26 columns]

# %%
n_nulls = df6['Country'].isnull().sum() #still  35 null values
print(n_nulls)
# Out:
# 35

# %% [markdown]
# We are going to do the same but trying to find information in the column "Location":

# %%
df6.loc[df6['Country'].isnull(), 'Country'] = df6['Location']
df6
# Out:
#      Case Number         Date  Year        Type             Country
# 0     2018.06.25  25-Jun-2018  2018     Boating                 USA  \
# 1     2018.06.18  18-Jun-2018  2018  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018    Provoked              MEXICO
# ...          ...          ...   ...         ...                 ...
# 6297     ND.0005  Before 1903  1903  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903  1903  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905  1900  Unprovoked                 USA
# 6300     ND.0002    1883-1889  1883  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853  1845  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity
# 0            California          Oceanside, San Diego County      Paddling  \
# 1               Georgia       St. Simon Island, Glynn County      Standing
# 2                Hawaii                         Habush, Oahu       Surfing
# 3       New South Wales                   Arrawarra Headland       Surfing
# 4                Colima                             La Ticla   Free diving
# ...                 ...                                  ...           ...
# 6297  Western Australia                          Roebuck Bay        Diving
# 6298  Western Australia                                  NaN  Pearl diving
# 6299     North Carolina                       Ocracoke Inlet      Swimming
# 6300                NaN                 Panama Bay 8ºN, 79ºW           NaN
# 6301   Eastern Province  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex   ...                             pdf
# 0               Julie Wolfe    F  ...            2018.06.25-Wolfe.pdf  \
# 1           Adyson McNeely     F  ...          2018.06.18-McNeely.pdf
# 2               John Denges    M  ...           2018.06.09-Denges.pdf
# 3                      male    M  ...        2018.06.08-Arrawarra.pdf
# 4            Gustavo Ramos     M  ...            2018.06.04-Ramos.pdf
# ...                     ...  ...  ...                             ...
# 6297                   male    M  ...          ND-0005-RoebuckBay.pdf
# 6298                  Ahmun    M  ...               ND-0004-Ahmun.pdf
# 6299  Coast Guard personnel    M  ...  ND-0003-Ocracoke_1900-1905.pdf
# 6300        Jules Patterson    M  ...      ND-0002-JulesPatterson.pdf
# 6301                   male    M  ...              ND-0001-Ceylon.pdf
#
#                                            href formula
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...  \
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25  \
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                 ...           ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0005
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0004
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0003
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0002
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0001
#
#      Case Number.2 original order Unnamed: 22 Unnamed: 23     New_Year
# 0       2018.06.25         6303.0         NaN         NaN  25-Jun-2018  \
# 1       2018.06.18         6302.0         NaN         NaN  18-Jun-2018
# 2       2018.06.09         6301.0         NaN         NaN  09-Jun-2018
# 3       2018.06.08         6300.0         NaN         NaN  08-Jun-2018
# 4       2018.06.04         6299.0         NaN         NaN  04-Jun-2018
# ...            ...            ...         ...         ...          ...
# 6297       ND.0005            6.0         NaN         NaN  Before 1903
# 6298       ND.0004            5.0         NaN         NaN  Before 1903
# 6299       ND.0003            4.0         NaN         NaN    1900-1905
# 6300       ND.0002            3.0         NaN         NaN    1883-1889
# 6301       ND.0001            2.0         NaN         NaN    1845-1853
#
#      All_years
# 0         2018
# 1         2018
# 2         2018
# 3         2018
# 4         2018
# ...        ...
# 6297      1903
# 6298      1903
# 6299      1900
# 6300      1883
# 6301      1845
#
# [6256 rows x 26 columns]

# %%
n_nulls2 = df6['Country'].isnull().sum() #29 null values. 
print(n_nulls2)
# Out:
# 29

# %% [markdown]
# As we can no get the location from another column, we assume all these values as nulls to our investigation as they don't have consistency.

# %%
df7 = df6.dropna(subset=["Country"])
df7
# Out:
#      Case Number         Date  Year        Type             Country
# 0     2018.06.25  25-Jun-2018  2018     Boating                 USA  \
# 1     2018.06.18  18-Jun-2018  2018  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018    Provoked              MEXICO
# ...          ...          ...   ...         ...                 ...
# 6297     ND.0005  Before 1903  1903  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903  1903  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905  1900  Unprovoked                 USA
# 6300     ND.0002    1883-1889  1883  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853  1845  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity
# 0            California          Oceanside, San Diego County      Paddling  \
# 1               Georgia       St. Simon Island, Glynn County      Standing
# 2                Hawaii                         Habush, Oahu       Surfing
# 3       New South Wales                   Arrawarra Headland       Surfing
# 4                Colima                             La Ticla   Free diving
# ...                 ...                                  ...           ...
# 6297  Western Australia                          Roebuck Bay        Diving
# 6298  Western Australia                                  NaN  Pearl diving
# 6299     North Carolina                       Ocracoke Inlet      Swimming
# 6300                NaN                 Panama Bay 8ºN, 79ºW           NaN
# 6301   Eastern Province  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex   ...                             pdf
# 0               Julie Wolfe    F  ...            2018.06.25-Wolfe.pdf  \
# 1           Adyson McNeely     F  ...          2018.06.18-McNeely.pdf
# 2               John Denges    M  ...           2018.06.09-Denges.pdf
# 3                      male    M  ...        2018.06.08-Arrawarra.pdf
# 4            Gustavo Ramos     M  ...            2018.06.04-Ramos.pdf
# ...                     ...  ...  ...                             ...
# 6297                   male    M  ...          ND-0005-RoebuckBay.pdf
# 6298                  Ahmun    M  ...               ND-0004-Ahmun.pdf
# 6299  Coast Guard personnel    M  ...  ND-0003-Ocracoke_1900-1905.pdf
# 6300        Jules Patterson    M  ...      ND-0002-JulesPatterson.pdf
# 6301                   male    M  ...              ND-0001-Ceylon.pdf
#
#                                            href formula
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...  \
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25  \
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                 ...           ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0005
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0004
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0003
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0002
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0001
#
#      Case Number.2 original order Unnamed: 22 Unnamed: 23     New_Year
# 0       2018.06.25         6303.0         NaN         NaN  25-Jun-2018  \
# 1       2018.06.18         6302.0         NaN         NaN  18-Jun-2018
# 2       2018.06.09         6301.0         NaN         NaN  09-Jun-2018
# 3       2018.06.08         6300.0         NaN         NaN  08-Jun-2018
# 4       2018.06.04         6299.0         NaN         NaN  04-Jun-2018
# ...            ...            ...         ...         ...          ...
# 6297       ND.0005            6.0         NaN         NaN  Before 1903
# 6298       ND.0004            5.0         NaN         NaN  Before 1903
# 6299       ND.0003            4.0         NaN         NaN    1900-1905
# 6300       ND.0002            3.0         NaN         NaN    1883-1889
# 6301       ND.0001            2.0         NaN         NaN    1845-1853
#
#      All_years
# 0         2018
# 1         2018
# 2         2018
# 3         2018
# 4         2018
# ...        ...
# 6297      1903
# 6298      1903
# 6299      1900
# 6300      1883
# 6301      1845
#
# [6227 rows x 26 columns]

# %%
n_nulls3 = df7['Country'].isnull().sum() #0 null values
print(n_nulls3)
# Out:
# 0

# %%
print(df7['Country'].unique())
# Out:
# ['USA' 'AUSTRALIA' 'MEXICO' 'BRAZIL' 'ENGLAND' 'SOUTH AFRICA' 'THAILAND'
#  'COSTA RICA' 'MALDIVES' 'BAHAMAS' 'NEW CALEDONIA' 'ECUADOR' 'MALAYSIA'
#  'LIBYA' 'CUBA' 'MAURITIUS' 'NEW ZEALAND' 'SPAIN' 'SAMOA'
#  'SOLOMON ISLANDS' 'JAPAN' 'EGYPT' 'ST HELENA, British overseas territory'
#  'COMOROS' 'REUNION' 'FRENCH POLYNESIA' 'UNITED KINGDOM'
#  'UNITED ARAB EMIRATES' 'PHILIPPINES' 'INDONESIA' 'CHINA' 'COLUMBIA'
#  'CAPE VERDE' 'Fiji' 'DOMINICAN REPUBLIC' 'CAYMAN ISLANDS' 'ARUBA'
#  'MOZAMBIQUE' 'FIJI' 'PUERTO RICO' 'ITALY' 'ATLANTIC OCEAN' 'GREECE'
#  'ST. MARTIN' 'FRANCE' 'PAPUA NEW GUINEA' 'TRINIDAD & TOBAGO' 'KIRIBATI'
#  'ISRAEL' 'DIEGO GARCIA' 'TAIWAN' 'JAMAICA' 'PALESTINIAN TERRITORIES'
#  'GUAM' 'SEYCHELLES' 'BELIZE' 'NIGERIA' 'TONGA' 'SCOTLAND' 'CANADA'
#  'CROATIA' 'SAUDI ARABIA' 'CHILE' 'ANTIGUA' 'KENYA' 'RUSSIA'
#  'TURKS & CAICOS' 'UNITED ARAB EMIRATES (UAE)' 'AZORES' 'SOUTH KOREA'
#  'MALTA' 'VIETNAM' 'MADAGASCAR' 'PANAMA' 'SOMALIA' 'NEVIS'
#  'BRITISH VIRGIN ISLANDS' 'NORWAY' 'SENEGAL' 'YEMEN' 'GULF OF ADEN'
#  'Sierra Leone' 'ST. MAARTIN' 'GRAND CAYMAN' 'Seychelles' 'LIBERIA'
#  'VANUATU' 'MEXICO ' 'HONDURAS' 'VENEZUELA' 'SRI LANKA' ' TONGA' 'URUGUAY'
#  'INDIA' 'MICRONESIA' 'CARIBBEAN SEA' 'OKINAWA' 'TANZANIA'
#  'MARSHALL ISLANDS' 'EGYPT / ISRAEL' 'NORTHERN ARABIAN SEA' 'HONG KONG'
#  'EL SALVADOR' 'ANGOLA' 'BERMUDA' 'MONTENEGRO' 'IRAN' 'English Channel'
#  'TUNISIA' 'NAMIBIA' 'NORTH ATLANTIC OCEAN' 'PORTUGAL' 'SOUTH CHINA SEA'
#  'BANGLADESH' 'PALAU' 'WESTERN SAMOA' 'PACIFIC OCEAN ' 'BRITISH ISLES'
#  'Caribbean Sea' 'GRENADA' 'IRAQ' 'TURKEY' 'NEW BRITAIN' 'SUDAN'
#  'JOHNSTON ISLAND' 'Florida Strait' 'SOUTH PACIFIC OCEAN' 'NEW GUINEA'
#  'RED SEA' 'NORTH PACIFIC OCEAN' 'FEDERATED STATES OF MICRONESIA'
#  'MID ATLANTIC OCEAN' 'ADMIRALTY ISLANDS' 'BRITISH WEST INDIES'
#  'SOUTH ATLANTIC OCEAN' 'PERSIAN GULF' 'RED SEA / INDIAN OCEAN'
#  'PACIFIC OCEAN' 'NORTH SEA' 'Between Timor & Darwin, Australia'
#  'NICARAGUA ' 'MALDIVE ISLANDS' 'AMERICAN SAMOA'
#  'ANDAMAN / NICOBAR ISLANDAS' 'GABON' 'Near the Andaman & Nicobar Islands'
#  'MAYOTTE' 'Between Comores & Madagascar' 'NORTH ATLANTIC OCEAN '
#  'SINGAPORE' 'THE BALKANS' 'SUDAN?' 'ARGENTINA' 'MARTINIQUE'
#  'INDIAN OCEAN' 'GUATEMALA' 'NETHERLANDS ANTILLES'
#  'NORTHERN MARIANA ISLANDS' 'IRAN / IRAQ' 'JAVA' 'SIERRA LEONE'
#  ' PHILIPPINES' '225 miles east of Hong Kong' 'NICARAGUA'
#  'CENTRAL PACIFIC' 'SOLOMON ISLANDS / VANUATU' 'Off South American coast'
#  'SOUTHWEST PACIFIC OCEAN' 'BAY OF BENGAL'
#  '300 miles east of St. Thomas (Virgin Islands)' 'MID-PACIFC OCEAN'
#  'SLOVENIA' 'CURACAO' 'ICELAND' 'ITALY / CROATIA' 'BARBADOS'
#  'French Southern Territories' 'MONACO' 'GUYANA' 'HAITI' 'SAN DOMINGO'
#  'IRELAND' 'KUWAIT' 'Near the equator' 'YEMEN ' 'REUNION ISLAND'
#  'FALKLAND ISLANDS' 'CRETE' 'CYPRUS' 'EGYPT ' 'WEST INDIES'
#  'Mediterranean Sea' 'BURMA' 'LEBANON' 'PARAGUAY' 'BRITISH NEW GUINEA'
#  'CEYLON' 'Gulf of California' 'OCEAN' 'GEORGIA' 'Western Banks'
#  'Santa Cruz' 'TUVALU' 'INDIAN OCEAN?' 'GUINEA' 'ANDAMAN ISLANDS'
#  'EQUATORIAL GUINEA / CAMEROON' 'COOK ISLANDS' 'TOBAGO' 'PERU' 'AFRICA'
#  'ALGERIA' 'Coast of AFRICA' 'TASMAN SEA' 'GHANA' 'St Helena' 'GREENLAND'
#  'MEDITERRANEAN SEA' 'SWEDEN' 'Carlisle Bay' 'ROATAN'
#  'Between PORTUGAL & INDIA' 'DJIBOUTI'
#  'In a river feeding into the Bay of Bengal' 'BAHREIN' 'KOREA' 'RED SEA?'
#  'ASIA?' 'CEYLON (SRI LANKA)']

# %%
df7['Country'] = df7['Country'].str.upper()
print(df7['Country'].unique())
# Out:
# ['USA' 'AUSTRALIA' 'MEXICO' 'BRAZIL' 'ENGLAND' 'SOUTH AFRICA' 'THAILAND'
#  'COSTA RICA' 'MALDIVES' 'BAHAMAS' 'NEW CALEDONIA' 'ECUADOR' 'MALAYSIA'
#  'LIBYA' 'CUBA' 'MAURITIUS' 'NEW ZEALAND' 'SPAIN' 'SAMOA'
#  'SOLOMON ISLANDS' 'JAPAN' 'EGYPT' 'ST HELENA, BRITISH OVERSEAS TERRITORY'
#  'COMOROS' 'REUNION' 'FRENCH POLYNESIA' 'UNITED KINGDOM'
#  'UNITED ARAB EMIRATES' 'PHILIPPINES' 'INDONESIA' 'CHINA' 'COLUMBIA'
#  'CAPE VERDE' 'FIJI' 'DOMINICAN REPUBLIC' 'CAYMAN ISLANDS' 'ARUBA'
#  'MOZAMBIQUE' 'PUERTO RICO' 'ITALY' 'ATLANTIC OCEAN' 'GREECE' 'ST. MARTIN'
#  'FRANCE' 'PAPUA NEW GUINEA' 'TRINIDAD & TOBAGO' 'KIRIBATI' 'ISRAEL'
#  'DIEGO GARCIA' 'TAIWAN' 'JAMAICA' 'PALESTINIAN TERRITORIES' 'GUAM'
#  'SEYCHELLES' 'BELIZE' 'NIGERIA' 'TONGA' 'SCOTLAND' 'CANADA' 'CROATIA'
#  'SAUDI ARABIA' 'CHILE' 'ANTIGUA' 'KENYA' 'RUSSIA' 'TURKS & CAICOS'
#  'UNITED ARAB EMIRATES (UAE)' 'AZORES' 'SOUTH KOREA' 'MALTA' 'VIETNAM'
#  'MADAGASCAR' 'PANAMA' 'SOMALIA' 'NEVIS' 'BRITISH VIRGIN ISLANDS' 'NORWAY'
#  'SENEGAL' 'YEMEN' 'GULF OF ADEN' 'SIERRA LEONE' 'ST. MAARTIN'
#  'GRAND CAYMAN' 'LIBERIA' 'VANUATU' 'MEXICO ' 'HONDURAS' 'VENEZUELA'
#  'SRI LANKA' ' TONGA' 'URUGUAY' 'INDIA' 'MICRONESIA' 'CARIBBEAN SEA'
#  'OKINAWA' 'TANZANIA' 'MARSHALL ISLANDS' 'EGYPT / ISRAEL'
#  'NORTHERN ARABIAN SEA' 'HONG KONG' 'EL SALVADOR' 'ANGOLA' 'BERMUDA'
#  'MONTENEGRO' 'IRAN' 'ENGLISH CHANNEL' 'TUNISIA' 'NAMIBIA'
#  'NORTH ATLANTIC OCEAN' 'PORTUGAL' 'SOUTH CHINA SEA' 'BANGLADESH' 'PALAU'
#  'WESTERN SAMOA' 'PACIFIC OCEAN ' 'BRITISH ISLES' 'GRENADA' 'IRAQ'
#  'TURKEY' 'NEW BRITAIN' 'SUDAN' 'JOHNSTON ISLAND' 'FLORIDA STRAIT'
#  'SOUTH PACIFIC OCEAN' 'NEW GUINEA' 'RED SEA' 'NORTH PACIFIC OCEAN'
#  'FEDERATED STATES OF MICRONESIA' 'MID ATLANTIC OCEAN' 'ADMIRALTY ISLANDS'
#  'BRITISH WEST INDIES' 'SOUTH ATLANTIC OCEAN' 'PERSIAN GULF'
#  'RED SEA / INDIAN OCEAN' 'PACIFIC OCEAN' 'NORTH SEA'
#  'BETWEEN TIMOR & DARWIN, AUSTRALIA' 'NICARAGUA ' 'MALDIVE ISLANDS'
#  'AMERICAN SAMOA' 'ANDAMAN / NICOBAR ISLANDAS' 'GABON'
#  'NEAR THE ANDAMAN & NICOBAR ISLANDS' 'MAYOTTE'
#  'BETWEEN COMORES & MADAGASCAR' 'NORTH ATLANTIC OCEAN ' 'SINGAPORE'
#  'THE BALKANS' 'SUDAN?' 'ARGENTINA' 'MARTINIQUE' 'INDIAN OCEAN'
#  'GUATEMALA' 'NETHERLANDS ANTILLES' 'NORTHERN MARIANA ISLANDS'
#  'IRAN / IRAQ' 'JAVA' ' PHILIPPINES' '225 MILES EAST OF HONG KONG'
#  'NICARAGUA' 'CENTRAL PACIFIC' 'SOLOMON ISLANDS / VANUATU'
#  'OFF SOUTH AMERICAN COAST' 'SOUTHWEST PACIFIC OCEAN' 'BAY OF BENGAL'
#  '300 MILES EAST OF ST. THOMAS (VIRGIN ISLANDS)' 'MID-PACIFC OCEAN'
#  'SLOVENIA' 'CURACAO' 'ICELAND' 'ITALY / CROATIA' 'BARBADOS'
#  'FRENCH SOUTHERN TERRITORIES' 'MONACO' 'GUYANA' 'HAITI' 'SAN DOMINGO'
#  'IRELAND' 'KUWAIT' 'NEAR THE EQUATOR' 'YEMEN ' 'REUNION ISLAND'
#  'FALKLAND ISLANDS' 'CRETE' 'CYPRUS' 'EGYPT ' 'WEST INDIES'
#  'MEDITERRANEAN SEA' 'BURMA' 'LEBANON' 'PARAGUAY' 'BRITISH NEW GUINEA'
#  'CEYLON' 'GULF OF CALIFORNIA' 'OCEAN' 'GEORGIA' 'WESTERN BANKS'
#  'SANTA CRUZ' 'TUVALU' 'INDIAN OCEAN?' 'GUINEA' 'ANDAMAN ISLANDS'
#  'EQUATORIAL GUINEA / CAMEROON' 'COOK ISLANDS' 'TOBAGO' 'PERU' 'AFRICA'
#  'ALGERIA' 'COAST OF AFRICA' 'TASMAN SEA' 'GHANA' 'ST HELENA' 'GREENLAND'
#  'SWEDEN' 'CARLISLE BAY' 'ROATAN' 'BETWEEN PORTUGAL & INDIA' 'DJIBOUTI'
#  'IN A RIVER FEEDING INTO THE BAY OF BENGAL' 'BAHREIN' 'KOREA' 'RED SEA?'
#  'ASIA?' 'CEYLON (SRI LANKA)']
# C:\Users\Leticia Martinez\AppData\Local\Temp\ipykernel_10416\2225390686.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df7['Country'] = df7['Country'].str.upper()

# %% [markdown]
# Now:
# 1. we are going to create a new Column "Ocean" in order to assign each country to an ocean.
# 2. create different lists with the Oceans of each country (list provided from external source)

# %%
north_atlantic = ['SENEGAL', 'COLUMBIA', 'USA', 'SCOTLAND', 'LIBERIA', 'MEXICO', 'VENEZUELA', 'MEXICO', 'OKINAWA', 'CAPE VERDE', 'BAHAMAS','CANADA', 'DENMARK', 'FAROE ISLANDS', 'GREENLAND', 'ICELAND', 'IRELAND', 'NORWAY', 'PORTUGAL', 'SPAIN', 'UNITED KINGDOM', 'ENGLAND', 'USA', 'BELGIUM', 'FRANCE', 'GERMANY', 'NETHERLANDS']
south_atlantic = ['ANGOLA', 'AZORES', 'NAMIBIA', 'ARGENTINA', 'BRAZIL', 'FALKLAND ISLANDS', 'GABON', 'NAMIBIA', 'SOUTH AFRICA', 'ST HELENA, BRITISH OVERSEAS TERRITORY', 'URUGUAY', 'ASCENSION ISLAND', 'BOUVET ISLAND', 'SOUTH GEORGIA AND THE SOUTH SANDWICH ISLANDS', 'TRISTAN DA CUNHA']
south_pacific = ['AUSTRALIA', 'NEW BRITAIN', 'NEW GUINEA','SAMOA','NEW CALEDONIA', 'CHILE', 'NEW ZEALAND','PAPUA NEW GUINEA', 'SOLOMON ISLANDS', 'COOK ISLANDS', 'EASTER ISLAND', 'FIJI', 'FRENCH POLYNESIA', 'KIRIBATI', 'NAURU', 'NIUE', 'NORFOLK ISLAND', 'PALAU', 'PAPUA NEW GUINEA', 'PITCAIRN ISLANDS', 'SOLOMON', 'TOKELAU', 'TONGA', 'TUVALU', 'VANUATU', 'AMERICAN SAMOA', 'CHRISTMAS ISLAND', 'COCOS (KEELING) ISLANDS', 'CORAL SEA ISLANDS', 'FEDERATED STATES OF MICRONESIA', 'FRENCH SOUTHERN AND ANTARCTIC LANDS', 'GUAM', 'HEARD ISLAND AND MCDONALD ISLANDS', 'MARSHALL ISLANDS', 'MIDWAY ISLANDS', 'NEW CALEDONIA', 'NIUE', 'NORFOLK ISLAND', 'NORTH KOREA', 'NORTHERN MARIANA ISLANDS', 'PALMYRA ATOLL', 'PAPUA NEW GUINEA', 'PITCAIRN ISLANDS', 'TIMOR-LESTE', 'TONGA', 'TUVALU', 'WALLIS AND FUTUNA']
north_pacific = ['CANADA', 'SIERRA LEONE','VIETNAM', 'SCOTLAND,' 'CHINA', 'JAPAN', 'MEXICO', 'RUSSIA', 'UNITED STATES', 'CAMBODIA', 'CHILE', 'COLOMBIA', 'COSTA RICA', 'ECUADOR', 'EL SALVADOR', 'GUATEMALA', 'HONDURAS', 'INDONESIA', 'KIRIBATI', 'NORTH KOREA', 'SOUTH KOREA', 'MARSHALL ISLANDS', 'MICRONESIA', 'NICARAGUA', 'PALAU', 'PANAMA', 'PHILIPPINES', 'RUSSIA', 'TAIWAN', 'THAILAND']
indian_ocean= ['REUNION', 'KENYA', 'TANZANIA', 'MADAGASCAR', 'COMOROS', 'MOZAMBIQUE', 'SOUTH AFRICA''MALDIVES', 'MAURITIUS', 'SOMALIA', 'SEYCHELLES', 'SRI LANKA', 'TANZANIA', 'MALAYSIA', 'MADAGASCAR']
mediterranean_sea=['SPAIN', 'ITALY', 'GREECE','MALTA', 'TUNISIA','TURKEY' 'LIBYA']
red_sea=['ISRAEL','YEMEN', 'EGYPT','SUDAN']
caribbean_sea=['PUERTO RICO', 'GRENADA','ARUBA', 'ANTIGUA','NICARAGUA', 'ST. MAARTIN', 'CUBA', 'TRINIDAD & TOBAGO', 'JAMAICA', 'CAYMAN ISLANDS', 'BRITISH VIRGIN ISLANDS', 'GRAND CAYMAN', 'COLOMBIA', 'DOMINICAN REPUBLIC', 'BELIZE', 'TURKS & CAICOS','BERMUDA']
adriatic_sea=['MONTENEGRO', 'CROATIA']
south_china_sea=['CHINA','HONG KONG']
persian_golf=['UNITED ARAB EMIRATES','UNITED ARAB EMIRATES (UAE)','IRAQ','IRAN', 'SAUDI ARABIA']
Bay_bengal_andaman_sea=['BURMA','MYANMAR','SRI LANKA', 'INDIA']

# %%
df7.insert(5, "Oceans", "")

# %%
for index, row in df7.iterrows():
    if row['Country'] in north_atlantic:
        df7.at[index, 'Oceans'] = 'North_Atlantic'

# %%
for index, row in df7.iterrows():
    if row['Country'] in south_atlantic:
        df7.at[index, 'Oceans'] = 'South_Atlantic'

# %%
for index, row in df7.iterrows():
    if row['Country'] in north_pacific:
        df7.at[index, 'Oceans'] = 'North_Pacific'

# %%
for index, row in df7.iterrows():
    if row['Country'] in south_pacific:
        df7.at[index, 'Oceans'] = 'South_pacific'

# %%
for index, row in df7.iterrows():
    if row['Country'] in mediterranean_sea:
        df7.at[index, 'Oceans'] = 'Mediterranean_Sea'

# %%
for index, row in df7.iterrows():
    if row['Country'] in caribbean_sea:
        df7.at[index, 'Oceans'] = 'Caribbean_Sea'

# %%
for index, row in df7.iterrows():
    if row['Country'] in Bay_bengal_andaman_sea:
        df7.at[index, 'Oceans'] = 'Bay_bengal_andaman_sea'

# %%
for index, row in df7.iterrows():
    if row['Country'] in red_sea:
        df7.at[index, 'Oceans'] = 'Red_Sea'

# %%
for index, row in df7.iterrows():
    if row['Country'] in indian_ocean:
        df7.at[index, 'Oceans'] = 'Indian_Ocean'

# %%
for index, row in df7.iterrows():
    if row['Country'] in south_china_sea:
        df7.at[index, 'Oceans'] = 'South_China_Sea'

# %%
for index, row in df7.iterrows():
    if row['Country'] in persian_golf:
        df7.at[index, 'Oceans'] = 'persian_golf'

# %%
for index, row in df7.iterrows():
    if row['Country'] in adriatic_sea:
        df7.at[index, 'Oceans'] = 'Adriatic_Sea'
df7
# Out:
#      Case Number         Date  Year        Type             Country
# 0     2018.06.25  25-Jun-2018  2018     Boating                 USA  \
# 1     2018.06.18  18-Jun-2018  2018  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018    Provoked              MEXICO
# ...          ...          ...   ...         ...                 ...
# 6297     ND.0005  Before 1903  1903  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903  1903  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905  1900  Unprovoked                 USA
# 6300     ND.0002    1883-1889  1883  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853  1845  Unprovoked  CEYLON (SRI LANKA)
#
#               Oceans               Area                             Location
# 0     North_Atlantic         California          Oceanside, San Diego County  \
# 1     North_Atlantic            Georgia       St. Simon Island, Glynn County
# 2     North_Atlantic             Hawaii                         Habush, Oahu
# 3      South_pacific    New South Wales                   Arrawarra Headland
# 4      North_Pacific             Colima                             La Ticla
# ...              ...                ...                                  ...
# 6297   South_pacific  Western Australia                          Roebuck Bay
# 6298   South_pacific  Western Australia                                  NaN
# 6299  North_Atlantic     North Carolina                       Ocracoke Inlet
# 6300   North_Pacific                NaN                 Panama Bay 8ºN, 79ºW
# 6301                   Eastern Province  Below the English fort, Trincomalee
#
#           Activity                   Name  ...
# 0         Paddling            Julie Wolfe  ...  \
# 1         Standing        Adyson McNeely   ...
# 2          Surfing            John Denges  ...
# 3          Surfing                   male  ...
# 4      Free diving         Gustavo Ramos   ...
# ...            ...                    ...  ...
# 6297        Diving                   male  ...
# 6298  Pearl diving                  Ahmun  ...
# 6299      Swimming  Coast Guard personnel  ...
# 6300           NaN        Jules Patterson  ...
# 6301      Swimming                   male  ...
#
#                                  pdf
# 0               2018.06.25-Wolfe.pdf  \
# 1             2018.06.18-McNeely.pdf
# 2              2018.06.09-Denges.pdf
# 3           2018.06.08-Arrawarra.pdf
# 4               2018.06.04-Ramos.pdf
# ...                              ...
# 6297          ND-0005-RoebuckBay.pdf
# 6298               ND-0004-Ahmun.pdf
# 6299  ND-0003-Ocracoke_1900-1905.pdf
# 6300      ND-0002-JulesPatterson.pdf
# 6301              ND-0001-Ceylon.pdf
#
#                                            href formula
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...  \
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25  \
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                 ...           ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0005
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0004
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0003
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0002
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0001
#
#      Case Number.2 original order Unnamed: 22 Unnamed: 23     New_Year
# 0       2018.06.25         6303.0         NaN         NaN  25-Jun-2018  \
# 1       2018.06.18         6302.0         NaN         NaN  18-Jun-2018
# 2       2018.06.09         6301.0         NaN         NaN  09-Jun-2018
# 3       2018.06.08         6300.0         NaN         NaN  08-Jun-2018
# 4       2018.06.04         6299.0         NaN         NaN  04-Jun-2018
# ...            ...            ...         ...         ...          ...
# 6297       ND.0005            6.0         NaN         NaN  Before 1903
# 6298       ND.0004            5.0         NaN         NaN  Before 1903
# 6299       ND.0003            4.0         NaN         NaN    1900-1905
# 6300       ND.0002            3.0         NaN         NaN    1883-1889
# 6301       ND.0001            2.0         NaN         NaN    1845-1853
#
#      All_years
# 0         2018
# 1         2018
# 2         2018
# 3         2018
# 4         2018
# ...        ...
# 6297      1903
# 6298      1903
# 6299      1900
# 6300      1883
# 6301      1845
#
# [6227 rows x 27 columns]

# %%
num_nullsoceans = df7['Oceans'].isna().sum() + df7['Oceans'].eq('').sum()
num_nullsoceans
# Out:
# 243

# %%
pd.set_option('display.max_rows', 30)

# create a boolean mask for null or empty 'Oceans' column
mask = df7['Oceans'].isnull() | df7['Oceans'].eq('')

# filter the rows using the mask and select the 'Country' column
countries_with_null_ocean = df7.loc[mask, 'Country']

# print the result
print(countries_with_null_ocean)
# Out:
# 23                 MALDIVES
# 59                    LIBYA
# 446          ATLANTIC OCEAN
# 538              ST. MARTIN
# 655            DIEGO GARCIA
#                ...
# 6237              SINGAPORE
# 6257    NORTH PACIFIC OCEAN
# 6269          PACIFIC OCEAN
# 6291                  ASIA?
# 6301     CEYLON (SRI LANKA)
# Name: Country, Length: 243, dtype: object

# %%
df_countries_with_null_ocean = pd.DataFrame({'Country': countries_with_null_ocean})
df_countries_with_null_ocean = df_countries_with_null_ocean.reset_index(drop=True)
from IPython.display import display, HTML
display(HTML(df_countries_with_null_ocean.to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Country</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>MALDIVES</td>
#     </tr>
#     <tr>
#       <td>LIBYA</td>
#     </tr>
#     <tr>
#       <td>ATLANTIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>ST. MARTIN</td>
#     </tr>
#     <tr>
#       <td>DIEGO GARCIA</td>
#     </tr>
#     <tr>
#       <td>PALESTINIAN TERRITORIES</td>
#     </tr>
#     <tr>
#       <td>NIGERIA</td>
#     </tr>
#     <tr>
#       <td>NEVIS</td>
#     </tr>
#     <tr>
#       <td>GULF OF ADEN</td>
#     </tr>
#     <tr>
#       <td>ATLANTIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>ATLANTIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>ATLANTIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>MEXICO</td>
#     </tr>
#     <tr>
#       <td>TONGA</td>
#     </tr>
#     <tr>
#       <td>TONGA</td>
#     </tr>
#     <tr>
#       <td>CARIBBEAN SEA</td>
#     </tr>
#     <tr>
#       <td>TONGA</td>
#     </tr>
#     <tr>
#       <td>EGYPT / ISRAEL</td>
#     </tr>
#     <tr>
#       <td>NORTHERN ARABIAN SEA</td>
#     </tr>
#     <tr>
#       <td>CARIBBEAN SEA</td>
#     </tr>
#     <tr>
#       <td>ENGLISH CHANNEL</td>
#     </tr>
#     <tr>
#       <td>NORTH ATLANTIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>SOUTH CHINA SEA</td>
#     </tr>
#     <tr>
#       <td>BANGLADESH</td>
#     </tr>
#     <tr>
#       <td>WESTERN SAMOA</td>
#     </tr>
#     <tr>
#       <td>PACIFIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>BRITISH ISLES</td>
#     </tr>
#     <tr>
#       <td>CARIBBEAN SEA</td>
#     </tr>
#     <tr>
#       <td>TURKEY</td>
#     </tr>
#     <tr>
#       <td>CARIBBEAN SEA</td>
#     </tr>
#     <tr>
#       <td>JOHNSTON ISLAND</td>
#     </tr>
#     <tr>
#       <td>PACIFIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>FLORIDA STRAIT</td>
#     </tr>
#     <tr>
#       <td>SOUTH PACIFIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>RED SEA</td>
#     </tr>
#     <tr>
#       <td>ATLANTIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>NORTH PACIFIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>MID ATLANTIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>ADMIRALTY ISLANDS</td>
#     </tr>
#     <tr>
#       <td>BRITISH WEST INDIES</td>
#     </tr>
#     <tr>
#       <td>SOUTH ATLANTIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>TURKEY</td>
#     </tr>
#     <tr>
#       <td>MID ATLANTIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>PERSIAN GULF</td>
#     </tr>
#     <tr>
#       <td>TURKEY</td>
#     </tr>
#     <tr>
#       <td>PERSIAN GULF</td>
#     </tr>
#     <tr>
#       <td>NORTH PACIFIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>ATLANTIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>RED SEA / INDIAN OCEAN</td>
#     </tr>
#     <tr>
#       <td>JOHNSTON ISLAND</td>
#     </tr>
#     <tr>
#       <td>PACIFIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>NORTH SEA</td>
#     </tr>
#     <tr>
#       <td>BETWEEN TIMOR &amp; DARWIN, AUSTRALIA</td>
#     </tr>
#     <tr>
#       <td>NICARAGUA</td>
#     </tr>
#     <tr>
#       <td>CARIBBEAN SEA</td>
#     </tr>
#     <tr>
#       <td>MALDIVE ISLANDS</td>
#     </tr>
#     <tr>
#       <td>CARIBBEAN SEA</td>
#     </tr>
#     <tr>
#       <td>NORTH ATLANTIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>TURKEY</td>
#     </tr>
#     <tr>
#       <td>MID ATLANTIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>ATLANTIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>TURKEY</td>
#     </tr>
#     <tr>
#       <td>ANDAMAN / NICOBAR ISLANDAS</td>
#     </tr>
#     <tr>
#       <td>PACIFIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>PACIFIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>PACIFIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>NEAR THE ANDAMAN &amp; NICOBAR ISLANDS</td>
#     </tr>
#     <tr>
#       <td>MAYOTTE</td>
#     </tr>
#     <tr>
#       <td>MID ATLANTIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>BETWEEN COMORES &amp; MADAGASCAR</td>
#     </tr>
#     <tr>
#       <td>NORTH PACIFIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>NORTH PACIFIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>NORTH ATLANTIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>SINGAPORE</td>
#     </tr>
#     <tr>
#       <td>THE BALKANS</td>
#     </tr>
#     <tr>
#       <td>SUDAN?</td>
#     </tr>
#     <tr>
#       <td>MARTINIQUE</td>
#     </tr>
#     <tr>
#       <td>PACIFIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>INDIAN OCEAN</td>
#     </tr>
#     <tr>
#       <td>NETHERLANDS ANTILLES</td>
#     </tr>
#     <tr>
#       <td>NORTH ATLANTIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>PACIFIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>SINGAPORE</td>
#     </tr>
#     <tr>
#       <td>CARIBBEAN SEA</td>
#     </tr>
#     <tr>
#       <td>NORTH PACIFIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>TURKEY</td>
#     </tr>
#     <tr>
#       <td>MID ATLANTIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>PACIFIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>PERSIAN GULF</td>
#     </tr>
#     <tr>
#       <td>IRAN / IRAQ</td>
#     </tr>
#     <tr>
#       <td>JAVA</td>
#     </tr>
#     <tr>
#       <td>PHILIPPINES</td>
#     </tr>
#     <tr>
#       <td>225 MILES EAST OF HONG KONG</td>
#     </tr>
#     <tr>
#       <td>CARIBBEAN SEA</td>
#     </tr>
#     <tr>
#       <td>NORTH PACIFIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>SOUTH PACIFIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>PACIFIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>PACIFIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>CENTRAL PACIFIC</td>
#     </tr>
#     <tr>
#       <td>CENTRAL PACIFIC</td>
#     </tr>
#     <tr>
#       <td>INDIAN OCEAN</td>
#     </tr>
#     <tr>
#       <td>PACIFIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>INDIAN OCEAN</td>
#     </tr>
#     <tr>
#       <td>SOLOMON ISLANDS / VANUATU</td>
#     </tr>
#     <tr>
#       <td>PACIFIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>OFF SOUTH AMERICAN COAST</td>
#     </tr>
#     <tr>
#       <td>ATLANTIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>ATLANTIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>SOUTHWEST PACIFIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>ATLANTIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>BAY OF BENGAL</td>
#     </tr>
#     <tr>
#       <td>300 MILES EAST OF ST. THOMAS (VIRGIN ISLANDS)</td>
#     </tr>
#     <tr>
#       <td>INDIAN OCEAN</td>
#     </tr>
#     <tr>
#       <td>MID-PACIFC OCEAN</td>
#     </tr>
#     <tr>
#       <td>SOUTHWEST PACIFIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>SOUTH ATLANTIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>SOUTH ATLANTIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>SOUTH ATLANTIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>SOUTH ATLANTIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>CARIBBEAN SEA</td>
#     </tr>
#     <tr>
#       <td>PACIFIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>SOUTH ATLANTIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>SOUTH ATLANTIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>ATLANTIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>SLOVENIA</td>
#     </tr>
#     <tr>
#       <td>PACIFIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>CURACAO</td>
#     </tr>
#     <tr>
#       <td>TURKEY</td>
#     </tr>
#     <tr>
#       <td>TURKEY</td>
#     </tr>
#     <tr>
#       <td>ITALY / CROATIA</td>
#     </tr>
#     <tr>
#       <td>TURKEY</td>
#     </tr>
#     <tr>
#       <td>BARBADOS</td>
#     </tr>
#     <tr>
#       <td>FRENCH SOUTHERN TERRITORIES</td>
#     </tr>
#     <tr>
#       <td>TURKEY</td>
#     </tr>
#     <tr>
#       <td>TURKEY</td>
#     </tr>
#     <tr>
#       <td>TURKEY</td>
#     </tr>
#     <tr>
#       <td>SOUTH ATLANTIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>MONACO</td>
#     </tr>
#     <tr>
#       <td>SINGAPORE</td>
#     </tr>
#     <tr>
#       <td>GUYANA</td>
#     </tr>
#     <tr>
#       <td>BARBADOS</td>
#     </tr>
#     <tr>
#       <td>HAITI</td>
#     </tr>
#     <tr>
#       <td>SAN DOMINGO</td>
#     </tr>
#     <tr>
#       <td>KUWAIT</td>
#     </tr>
#     <tr>
#       <td>LIBYA</td>
#     </tr>
#     <tr>
#       <td>ATLANTIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>GUYANA</td>
#     </tr>
#     <tr>
#       <td>NIGERIA</td>
#     </tr>
#     <tr>
#       <td>NORTH ATLANTIC OCEAN</td>
#     </tr>
#     <tr>
#       <td>NEAR THE EQUATOR</td>
#     </tr>
#     <tr>
#       <td>HAITI</td>
#     </tr>
#     <tr>
#       <td>YEMEN</td>
#     </tr>
#     <tr>
#       <td>INDIAN OCEAN</td>
#     </tr>
#     <tr>
#       <td>REUNION ISLAND</td>
#     </tr>
#     <tr>
#       <td>CRETE</td>
#     </tr>
#     <tr>
#       <td>CYPRUS</td>
#     </tr>
#     <tr>
#       <td>YEMEN</td>
#     </tr>
#     <tr>
#       <td>LIBYA</td>
#     </tr>
#     <tr>
#       <td>LIBYA</td>
#     </tr>
#     <tr>
#       <td>EGYPT</td>
#     </tr>
#     <tr>
#       <td>EGYPT</td>
#     </tr>
#     <tr>
#       <td>WEST INDIES</td>
#     </tr>
#     <tr>
#       <td>Y

# %% [markdown]
# ### TIME CLEANING DATA

# %% [markdown]
# - First, we are going to clean the column year to remove all the null values in year as we are not consider the ones empty.
# As we we are going to considerer null values all the values that ar enot real years as "0, 5, 77, 500".
# We are going to use a function that removes all the values in Year that does not contain 4 digits
# Verify from which year are more attacks reported. With this assumption we check if before 80', maybe, many cases were not reported. With this we will have more accurate data about which is the ocean with more attacaks ommiting data that can make out data scatter- '

# %%
df7['Time'].unique()
# Out:
# array(['18h00', '14h00  -15h00', '07h45', nan, 'Late afternoon', '17h00',
#        '14h00', 'Morning', '15h00', '08h15', '11h00', '10h30', '10h40',
#        '16h50', '07h00', '09h30', 'Afternoon', '21h50', '09h40', '08h00',
#        '17h35', '15h30', '07h30', '19h00, Dusk', 'Night', '16h00',
#        '15h01', '12h00', '13h45', '23h30', '09h00', '14h30', '18h30',
#        '12h30', '16h30', '18h45', '06h00', '10h00', '10h44', '13h19',
#        'Midday', '13h30', '10h45', '11h20', '11h45', '19h30', '08h30',
#        '15h45', 'Shortly before 12h00', '17h34', '17h10', '11h15',
#        '08h50', '17h45', '13h00', '10h20', '13h20', '02h00', '09h50',
#        '11h30', '17h30', '9h00', '10h43', 'After noon', '15h15', '15h40',
#        '19h05', '1300', '14h30 / 15h30', '22h00', '16h20', '14h34',
#        '15h25', '14h55', '17h46', 'Morning ', '15h49', '19h00',
#        'Midnight', '09h30 / 10h00', '10h15', '18h15', '04h00', '14h50',
#        '13h50', '19h20', '10h25', '10h45-11h15', '16h45', '15h52',
#        '06h15', '14h40', '19h45', '10h10', '08h45', 'Evening', '12h10',
#        '18h05', '11h41', '12h25', '17h51', '16h12', '12h45', '10h50',
#        '14h15', '09h45', '06h45', '05h00', '03h30',
#        'Sometime between 06h00 & 08hoo', '06h30', '17h20', '20h00',
#        '16h40', '16h18', '11h10', 'Early afternoon', '17h50',
#        '07h00 - 08h00', '18h15-18h30', '17h01', '09h57', '08h20', '17h58',
#        '20h30', '15h19', '10h55', '15h55', '23h00', '12h40', '13h55',
#        '16h05', '14h10', '15h20', '12h50', '14h45', '13h40', '13h24',
#        '09h00 - 09h30', '0830', '11h40', '08h10', '15h56', '14h20',
#        'Just before noon', '07h56', '1600', '17h17', '16h35', '09h05',
#        '07h15', '07h20', '19h28', '12h38', '05h50', '15h50', '11h05',
#        'Early morning', 'Dawn', '05h45', '13h25', '12h20', '13h26',
#        '09h11', '12h15', '13h15', '18h20', '15h35', 'AM', '13h51', 'A.M.',
#        '08h05', '19h15', '10h35', '15h44', 'Dusk', '21h00', 'Lunchtime',
#        '15j45', '09h35', '10h27', '10h16', '0500', 'Before 07h00',
#        '09h20', '10h00 -- 11h00', '12h05', '14h21', '18h50', '15h53',
#        '"Just before 11h00"', '11h115', '13h42', '20h15', '12h39',
#        '07h05', 'Sunset', '  ', '13h05', '11h50', '"Evening"',
#        'Just before sundown', '22h30', '17h15', '17h55', '16h10',
#        '11h30 ', '06h10', '16h15', 'Between 05h00 and 08h00', '07h08',
#        '17h00 or 17h40', '03h00', '>08h00', '--', '12h02', '12h55',
#        '16h14', '17h11', '00h30', '14h37', '10h07', '13h53', '11h55',
#        '13h23', 'Just after 12h00', '02h30', '08h40', '11h56', '14h35',
#        ' ', 'Early Morning', '07h50', 'Shortly after midnight', '14h25',
#        '13h345', '\xa0 ', '06h47', '09h00 -10h00', '20h45 (Sunset)',
#        'Late morning', 'P.M.', '18h40', '13h14', '13h06',
#        'Shortly before 13h00', '12h34', '11h53', '8:04 pm', '12h46',
#        '12h48', '17h42', '12h35', 'Possibly same incident as 2000.08.21',
#        'After Dusk', '11h57', 'Noon', '17h40', '11h25', '18h25', '10h28',
#        '09h15', '14h16', '09h55', '2 hours after Opperman', '15h05',
#        '09h30 ', 'Mid afternoon', 'Mid morning', '11h48', '11h00 / 11h30',
#        '07h19', '13h37', '11h06', '"Night"', '18h30?', '11h58', '11h51',
#        '18h12', '07h10', '07h40', '12h33',
#        '30 minutes after 1992.07.08.a', '>06h45', '15h06', '12h54',
#        'Between 06h00 & 07h20', '16h55', '05h40', '<07h30', '21h30',
#        '17h00 Sunset', 'Nightfall', 'X', '08h57', '18h30 (Sunset)',
#        '06j00', '08h35', '10h22', '02h45', 'Prior to 10h37', 'Daybreak',
#        '18h10', '>12h00', 'Mid-morning', '08h55', '16h30 or 18h00',
#        'Just before dawn', ' 14h00', 'Daytime', '06h50', '01h00', 'Dark',
#        '10h00 / 11h00', '"After lunch"', '07h32', '15h00 or 15h45',
#        '>17h00', '19h00 / 20h00', '12h45 / 13h45', '14h00 - 15h00',
#        '03h45 - 04h00', '13h10', '09h30 / 15h30', '08h00 / 09h30',
#        '19h35', '12h00 to 14h00', '13h35', 'Late night', '01h32',
#        '10h30 or 13h30', '16h23', '15h00j', 'Midday.', '"After dark"',
#        '10h00 or 14h00', '19h10', '16h25', '2 hrs before sunset',
#        '18h15 to 21h30', '1500', '"shortly before dusk"', '>17h30',
#        '>14h30', 'Between 11h00 & 12h00', 'After 04h00',
#        '11h01 -time of ship sinking', 'Ship aban-doned at 03h10', '19h55',
#        'After dusk',
#        'FATAL  (Wire netting installed at local beaches after this incident.)',
#        '01h30', 'After midnight', 'Late afternon', '05h30',
#        '"Early evening"', 'Late Afternoon', '   ', 'Before daybreak',
#        'dusk', 'Before 10h30', '06h00 -- 07h00', '01h50', '17h00-18h00',
#        '19h00-20h00'], dtype=object)

# %%
n_nulls_years = df7['Time'].isnull().sum()
print(n_nulls_years)
# Out:
# 3295

# %% [markdown]
# Even there are more than 50% null vallues, we will clean the data to analyze when it's more likely to have an attack: at sunrise time, morning, afternoon or night.

# %%
df8 = df7.dropna(subset=["Time"])
df8
# Out:
#        Case Number                  Date  Year        Type   Country
# 0       2018.06.25           25-Jun-2018  2018     Boating       USA  \
# 1       2018.06.18           18-Jun-2018  2018  Unprovoked       USA
# 2       2018.06.09           09-Jun-2018  2018     Invalid       USA
# 6     2018.06.03.a           03-Jun-2018  2018  Unprovoked    BRAZIL
# 8     2018.05.26.b           26-May-2018  2018  Unprovoked       USA
# ...            ...                   ...   ...         ...       ...
# 6228       ND.0085  No date, Before 1969  1969  Unprovoked  RED SEA?
# 6241       ND.0065                 1960s  1960  Unprovoked      IRAQ
# 6242       ND.0064                 1960s  1960  Unprovoked      IRAQ
# 6243       ND.0063                 1960s  1960  Unprovoked      IRAQ
# 6265       ND.0038             1941-1942  1941  Unprovoked      IRAQ
#
#               Oceans        Area                                     Location
# 0     North_Atlantic  California                  Oceanside, San Diego County  \
# 1     North_Atlantic     Georgia               St. Simon Island, Glynn County
# 2     North_Atlantic      Hawaii                                 Habush, Oahu
# 6     South_Atlantic  Pernambuco                        Piedade Beach, Recife
# 8     North_Atlantic     Florida                 Cocoa Beach, Brevard  County
# ...              ...         ...                                          ...
# 6228                         NaN                                          NaN
# 6241    persian_golf      Basrah                          Shatt-al-Arab River
# 6242    persian_golf      Basrah                         Shatt-al-Arab River
# 6243    persian_golf      Basrah       Shatt-al-Arab River near Abu al Khasib
# 6265    persian_golf      Basrah  Shatt-el Arab River near a small boat stand
#
#                                                Activity
# 0                                              Paddling  \
# 1                                              Standing
# 2                                               Surfing
# 6                                              Swimming
# 8                                               Walking
# ...                                                 ...
# 6228                                        Free diving
# 6241  Fishing from a small boat & put his hand in th...
# 6242  Swimming naked near a date palm where many dat...
# 6243  Swimming in section of river used for washing ...
# 6265                                           Swimming
#
#                         Name  ...                        pdf
# 0                Julie Wolfe  ...       2018.06.25-Wolfe.pdf  \
# 1            Adyson McNeely   ...     2018.06.18-McNeely.pdf
# 2                John Denges  ...      2018.06.09-Denges.pdf
# 6     Jose Ernesto da Silva   ...   2018.06.03.a-daSilva.pdf
# 8                  Cody High  ...      2018.05.26.b-High.pdf
# ...                      ...  ...                        ...
# 6228               Jill Reed  ...       ND-0085-JillReed.pdf
# 6241                    male  ...       ND-0065-deadfish.pdf
# 6242                    male  ...  ND-0064-Shatt-al-Arab.pdf
# 6243                    male  ...  ND-0063-Shatt-al-Arab.pdf
# 6265                    male  ...  ND-0038-Shatt-al-Arab.pdf
#
#                                            href formula
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...  \
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 6     http://sharkattackfile.net/spreadsheets/pdf_di...
# 8     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6228  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6241  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6242  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6243  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6265  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25  \
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 6     http://sharkattackfile.net/spreadsheets/pdf_di...  2018.06.03.a
# 8     http://sharkattackfile.net/spreadsheets/pdf_di...  2018.05.26.b
# ...                                                 ...           ...
# 6228  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0085
# 6241  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0065
# 6242  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0064
# 6243  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0063
# 6265  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0038
#
#      Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0       2018.06.25         6303.0         NaN         NaN  \
# 1       2018.06.18         6302.0         NaN         NaN
# 2       2018.06.09         6301.0         NaN         NaN
# 6     2018.06.03.a         6297.0         NaN         NaN
# 8     2018.05.26.b         6295.0         NaN         NaN
# ...            ...            ...         ...         ...
# 6228       ND.0085           75.0         NaN         NaN
# 6241       ND.0065           62.0         NaN         NaN
# 6242       ND.0064           61.0         NaN         NaN
# 6243       ND.0063           60.0         NaN         NaN
# 6265       ND.0038           38.0         NaN         NaN
#
#                   New_Year All_years
# 0              25-Jun-2018      2018
# 1              18-Jun-2018      2018
# 2              09-Jun-2018      2018
# 6              03-Jun-2018      2018
# 8              26-May-2018      2018
# ...                    ...       ...
# 6228  No date, Before 1969      1969
# 6241                 1960s      1960
# 6242                 1960s      1960
# 6243                 1960s      1960
# 6265             1941-1942      1941
#
# [2932 rows x 27 columns]

# %%
df8['Cleaned_Time'] = df8['Time'].str.extract(r'^(\d+)h')
df8
# Out:
# C:\Users\Leticia Martinez\AppData\Local\Temp\ipykernel_10416\3729706286.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df8['Cleaned_Time'] = df8['Time'].str.extract(r'^(\d+)h')
#        Case Number                  Date  Year        Type   Country
# 0       2018.06.25           25-Jun-2018  2018     Boating       USA  \
# 1       2018.06.18           18-Jun-2018  2018  Unprovoked       USA
# 2       2018.06.09           09-Jun-2018  2018     Invalid       USA
# 6     2018.06.03.a           03-Jun-2018  2018  Unprovoked    BRAZIL
# 8     2018.05.26.b           26-May-2018  2018  Unprovoked       USA
# ...            ...                   ...   ...         ...       ...
# 6228       ND.0085  No date, Before 1969  1969  Unprovoked  RED SEA?
# 6241       ND.0065                 1960s  1960  Unprovoked      IRAQ
# 6242       ND.0064                 1960s  1960  Unprovoked      IRAQ
# 6243       ND.0063                 1960s  1960  Unprovoked      IRAQ
# 6265       ND.0038             1941-1942  1941  Unprovoked      IRAQ
#
#               Oceans        Area                                     Location
# 0     North_Atlantic  California                  Oceanside, San Diego County  \
# 1     North_Atlantic     Georgia               St. Simon Island, Glynn County
# 2     North_Atlantic      Hawaii                                 Habush, Oahu
# 6     South_Atlantic  Pernambuco                        Piedade Beach, Recife
# 8     North_Atlantic     Florida                 Cocoa Beach, Brevard  County
# ...              ...         ...                                          ...
# 6228                         NaN                                          NaN
# 6241    persian_golf      Basrah                          Shatt-al-Arab River
# 6242    persian_golf      Basrah                         Shatt-al-Arab River
# 6243    persian_golf      Basrah       Shatt-al-Arab River near Abu al Khasib
# 6265    persian_golf      Basrah  Shatt-el Arab River near a small boat stand
#
#                                                Activity
# 0                                              Paddling  \
# 1                                              Standing
# 2                                               Surfing
# 6                                              Swimming
# 8                                               Walking
# ...                                                 ...
# 6228                                        Free diving
# 6241  Fishing from a small boat & put his hand in th...
# 6242  Swimming naked near a date palm where many dat...
# 6243  Swimming in section of river used for washing ...
# 6265                                           Swimming
#
#                         Name  ...
# 0                Julie Wolfe  ...  \
# 1            Adyson McNeely   ...
# 2                John Denges  ...
# 6     Jose Ernesto da Silva   ...
# 8                  Cody High  ...
# ...                      ...  ...
# 6228               Jill Reed  ...
# 6241                    male  ...
# 6242                    male  ...
# 6243                    male  ...
# 6265                    male  ...
#
#                                            href formula
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...  \
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 6     http://sharkattackfile.net/spreadsheets/pdf_di...
# 8     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6228  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6241  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6242  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6243  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6265  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25  \
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 6     http://sharkattackfile.net/spreadsheets/pdf_di...  2018.06.03.a
# 8     http://sharkattackfile.net/spreadsheets/pdf_di...  2018.05.26.b
# ...                                                 ...           ...
# 6228  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0085
# 6241  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0065
# 6242  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0064
# 6243  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0063
# 6265  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0038
#
#      Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0       2018.06.25         6303.0         NaN         NaN  \
# 1       2018.06.18         6302.0         NaN         NaN
# 2       2018.06.09         6301.0         NaN         NaN
# 6     2018.06.03.a         6297.0         NaN         NaN
# 8     2018.05.26.b         6295.0         NaN         NaN
# ...            ...            ...         ...         ...
# 6228       ND.0085           75.0         NaN         NaN
# 6241       ND.0065           62.0         NaN         NaN
# 6242       ND.0064           61.0         NaN         NaN
# 6243       ND.0063           60.0         NaN         NaN
# 6265       ND.0038           38.0         NaN         NaN
#
#                   New_Year All_years Cleaned_Time
# 0              25-Jun-2018      2018           18
# 1              18-Jun-2018      2018           14
# 2              09-Jun-2018      2018           07
# 6              03-Jun-2018      2018          NaN
# 8              26-May-2018      2018           17
# ...                    ...       ...          ...
# 6228  No date, Before 1969      1969          NaN
# 6241                 1960s      1960          NaN
# 6242                 1960s      1960          NaN
# 6243                 1960s      1960          NaN
# 6265             1941-1942      1941          NaN
#
# [2932 rows x 28 columns]

# %%
# update the 'Time' column with values from 'Cleaned_Time'
df8.loc[df8['Cleaned_Time'].str.contains(r'^\d{2}$') & df8['Cleaned_Time'].notnull(), 'Time'] = df8['Cleaned_Time']
subset = df8.loc[:, ['Time', 'Cleaned_Time']]
subset
# Out:
#                 Time Cleaned_Time
# 0                 18           18
# 1                 14           14
# 2                 07           07
# 6     Late afternoon          NaN
# 8                 17           17
# ...              ...          ...
# 6228         Morning          NaN
# 6241       Afternoon          NaN
# 6242       Afternoon          NaN
# 6243       Afternoon          NaN
# 6265       Afternoon          NaN
#
# [2932 rows x 2 columns]
